# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver import ActionChains
from bs4 import BeautifulSoup
import requests
from urllib.parse import urljoin
import pandas as pd
import time
import subprocess
import os

# %%
import re
import requests
from requests_html import HTML
import pandas as pd

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver import DesiredCapabilities
from selenium.common.exceptions import TimeoutException, NoSuchElementException, TimeoutException, ElementClickInterceptedException

# %%
def chrome(url):
#     subprocess.run('mkdir /tmp/bin', shell=True)
#     os.system("cp ./chromedriver /tmp/bin/chromedriver")
#     os.system("cp ./headless-chromium /tmp/bin/headless-chromium")
#     os.chmod("/tmp/bin/chromedriver", 0o777)
#     os.chmod("/tmp/bin/headless-chromium", 0o777)
#     driver = webdriver.Chrome('/path/to/chromedriver')
    options = webdriver.ChromeOptions()
#     options.binary_location=r"C:\Users\00049952\scrapping\headless-chromium"
    options.add_argument("--headless")
    options.add_argument("--disable-gpu")
    options.add_argument("--single-process")
    options.add_argument("--no-sandbox")
    options.add_argument("--disable-dev-shm-usage")
    options.add_argument("--window-size=1600x800") # can be changed to any browser size
    browser = webdriver.Chrome(options=options)
    browser.implicitly_wait(10)
    browser.set_page_load_timeout(20)
    browser.get(url)
    return browser.page_source, browser

# %%
def chrome(url):
    
    # support to get response status and headers
    d = DesiredCapabilities.CHROME
    d['loggingPrefs'] = {'performance': 'ALL'}
    opt = webdriver.ChromeOptions()
#     opt.add_argument("--headless")
#     opt.add_argument("--disable-xss-auditor")
    opt.add_argument("--disable-web-security")
    opt.add_argument("--allow-running-insecure-content")
    opt.add_argument("--no-sandbox")
    opt.add_argument("--disable-setuid-sandbox")
    opt.add_argument("--disable-webgl")
    opt.add_argument("--disable-popup-blocking")
    # prefs = {"profile.managed_default_content_settings.images": 2,
    #          'notifications': 2,
    #          }
    # opt.add_experimental_option("prefs", prefs)
    browser = webdriver.Chrome(options=opt,desired_capabilities=d)
#     browser.add_cookie({"name" : "_session_public", "value" : "EMDkrM2AsLpsnFEu3L9bkz6oS7QUnbVWyXBOW1SpMpozxRwuSTZHwkIxaia0zESLkJUK6BxDmOAv3L7yycPsWi6voEhuZkW7iB7J"})
#     browser.add_cookie({"name" : "city", "value" : "{%22id%22:1%2C%22name%22:%22%D0%90%D0%BB%D0%BC%D0%B0%D1%82%D1%8B%22%2C%22slug%22:%22almaty%22%2C%22is_disabled%22:false%2C%22deposit_rate%22:1%2C%22label%22:%22empty%22%2C%22country_id%22:1%2C%22latitude%22:43.221313%2C%22longitude%22:76.955436}"})
    browser.implicitly_wait(10)
    browser.set_page_load_timeout(20)
    browser.get(url)
    return browser.page_source, browser

# %%
url = 'https://naimi.kz/#/'
req = requests.get(url)
content, browser = chrome(url)

# %%
content

# %%
content

# %%
# /en/fabric/7137786-genevieve-floral-by-crystal_walen
def extract_id_slug(url_path):
    regex = r"^[^\s]+/(?P<id>\d+)./?service=(?P<service>\d+)"
    group = re.match(regex, url_path)
    if not group:
        return None, None
    return group['id'], group['service']

# %%
category=[]
list_cat_hrefs=[]
url = 'https://naimi.kz/#/'
req = requests.get(url)
content, browser = chrome(url)
browser.find_element_by_xpath("//button[@class='btn blue mr-3 flex-item']").click()

# %%
elements=browser.find_elements_by_class_name("category")
for i in elements:
    elements = i.find_elements_by_tag_name("a")
    for el in elements:
        category.append(el)
        list_cat_hrefs.append(el.get_attribute("href"))

# %%
list_cat_hrefs

# %%
list_sub_cat_hrefs=[]
for l in list_cat_hrefs:
    req = requests.get(l)
    content, browser = chrome(l)
    cats=browser.find_elements_by_xpath("//a[@class='categories--service blue outline pt-1 pb-1 pl-2 pr-2']")
    for i in cats:
        print(i.get_attribute("href"))
        list_sub_cat_hrefs.append(i.get_attribute("href"))

# %%
len(list_sub_cat_hrefs)

# %%
datas = []
for cat in list_sub_cat_hrefs:
    i=1
    result = None
    text_found=r'Рекомендованные специалисты'
    while text_found is not None:
        try:
            url = '{}?page={}#/'.format(cat,i)
            req = requests.get(url)
            content, browser = chrome(url)
            html_r = HTML(html=content)
            text_found = re.search(r'Рекомендованные специалисты', content)
            if text_found is None:
                break
            list_of_hrefs=[]
            a_elements = []
            content_blocks = browser.find_elements_by_class_name("service-specialists")
            for block in content_blocks:
                elements = block.find_elements_by_tag_name("a")
                for el in elements:
                    a_elements.append(el)
                    list_of_hrefs.append(el.get_attribute("href"))
                    fabric_links = [x for x in list(list_of_hrefs) if x.startswith("https://naimi.kz/specialist/")]
            for path in fabric_links:
                id_, slug_ = extract_id_slug(path)
                print(id_, slug_)
                data = {
                    "id": id_,
                    "slug": slug_,
                    "path": path,
                    "scraped": 0 # True / False -> 1 / 0 
                }
                datas.append(data)
            print('page {}'.format(i))   
            i+=1    
        except:
            break

# %%
datas

# %%
# !pipenv install pickle

# %%
import pickle

# %%
with open(r'datas.pickle', 'wb') as output:
    pickle.dump(datas, output)

# %%
with open(r'datas.pickle', 'rb') as data:
     datas = pickle.load(data)

# %%
len(datas[:8000])

# %%
len(datas[8000:])

# %%
cookies={1:{"name" : "_session_public", "value" : "5pZTFel7yzs2v45x3aSV5GAXLBIwLKGhAU9DAdJKx5DwBudoiZBTcOxtb59SpTBFYkLfZdXCruadau40TeEdB3iZ5JfhlwyndNDv"},
        2:{"name" : "_session_public", "value" : "olUZpkrCCqkBw3acekj6dFVS0QdsonoRkIpr6AvaOTmbRDyJuu7ZpqDS5y0uD6l1YLKFKD5yOLlILQrWuUUyXIblx25OrbeCkkM9"},
        3:{"name" : "_session_public", "value" : "Vgc0HsG34m0zYQyJBvrlGukCSqvxYecOvRYHfuWwDaPEPOLELG8CPGYigjIBNzwsOOlCRQanplQpw2oYzWlysxbBJsLbmU89SjIL"},
        4:{"name" : "_session_public", "value" : "OhwTjaD9huk1qvEMmqGKdzwRNvNHQwxeBq7UKkfLZDPO2SX3ux9NizwxqTjAjpW58VO1idGnQR7ta9mvcWgOwd20tiER9hRnHaWI"},
        5:{"name" : "_session_public", "value" : "PZQNzME5q4YRqIIgzJOEPKvTvlueobznww0DcT9MoagB69SwfIuS1ZX126LurmOnMSK7FhKBGnfK6ykU37MSKoNxMe8EgZyx7En0"},
        6:{"name" : "_session_public", "value" : "Mp4pnLF8ZXyNR4nEE9AzLDTC6KpaFZ2NZ4DyLzxGPjbNL3Z4mTr5iCyWdX4Hn4INIrBVPDkHw4UdkhcgfVuYw86kCtHhC2ld4mFR"},
        7:{"name" : "_session_public", "value" : "tthelPcHx8BspcH3xbMjvKT9HwTCOP6YnxfeKVQc2AePKwKTtz9Ny4XpjbDPSrCotP0Zvl3AQPWorDNs7J3c6krZU7wSMz01HbFT"},
        }

# %%
cookies={1:{"name" : "_session_public", "value" : "UKUGE7TaTmQfOtOJoOB3BQWcMFdJnXkQv6iID1kIJ7caN71IhBK17IMH1E53ehZV7rMpRNWb7vv1wnhwUcDe1KDPliUfDRoF8Pwr"},
         2:{"name" : "_session_public", "value" : "QYKqCLbbsWJHFtsnH77H29vLC7W8d8fPbUJp1jL18ZoteNbECxBppB3jBFMG9Lmko2qTJ0gqQo99HYCkINAZJYCRi6GyWSce2UEe"},
         3:{"name" : "_session_public", "value" : "L2Jg7XO6PrEBJI8DLrGWpxVKqh58YuVXw7tHADFvab3H5OwYez4y3o19LFayM3xCnfNKSy23IBLw87Hk4ZYQqKrsZEF8nirtdCkf"}}

# %%
len(not_done)
# Out:
# 15779

# %%
start = time.time()
i=1
q=1
for p in not_done[:6000]:
    try:
        if i%50!=0:
            url = p.get('path')
            req = requests.get(url)
            content, browser = chrome(url)
            browser.add_cookie(cookies.get(q))
            print("{}  {}".format(p.get('path'), q))
            html_r = HTML(html=content)          
            try:
                browser.find_element_by_xpath("//button[@class='btn blue mr-3 flex-item']").click()
            except NoSuchElementException:
                pass
            except ElementClickInterceptedException:
                pass
            try:
                p["name"] = element_name = browser.find_element_by_xpath("//div[@class='mb-half text lg verified']").text
            except NoSuchElementException:
                p["name"]=None
                pass
            try:
                p["age"] = browser.find_elements_by_xpath("//span[@class='text md gray-75 d-ib mr-1']")[0].text
            except NoSuchElementException:
                p["age"]=None
                pass
            try:
                p["exp"] = browser.find_elements_by_xpath("//span[@class='text md gray-75 d-ib ml-1']")[0].text
            except NoSuchElementException:
                p["exp"]=None
                pass
            try:
                p['price']= browser.find_element_by_xpath("//div[@class='flex-item fixed-size right']").text
            except NoSuchElementException:
                p['price']=None
                pass
            try:
                p['spec_lvl']=browser.find_elements_by_xpath("//span[@class='specialist--level text md']")[0].text
            except NoSuchElementException:
                p['spec_lvl']=None
                pass
            try:
                p['review-count']=browser.find_elements_by_xpath("//div[@class='flex-item fixed-size review--review-count mr-4']")[0].text
            except NoSuchElementException:
                p['review-count']=None
                pass
            try:
                p['review-positive']=browser.find_element_by_xpath("//div[@class='review--review-bars positive']//div[@class='review--review-bar']").get_attribute("style")
            except NoSuchElementException:
                p['review-positive']=None
                pass
            try:
                p['review-neutral']=browser.find_element_by_xpath("//div[@class='review--review-bars neutral']//div[@class='review--review-bar']").get_attribute("style")
            except NoSuchElementException:
                p['review-neutral']=None
                pass
            try:
                p['review-negative']=browser.find_element_by_xpath("//div[@class='review--review-bars negative']//div[@class='review--review-bar']").get_attribute("style")
            except NoSuchElementException:
                p['review-negative']=None
                pass
            try:
                p['edu_prof']=browser.find_element_by_xpath("//div[@class='text md']").text
            except NoSuchElementException:
                p['edu_prof']=None
                pass
            try:
                p['edu_university']=browser.find_element_by_xpath("//div[@class='text sm gray']").text
            except NoSuchElementException:
                p['edu_university']=None
                pass
            try:
                browser.find_element_by_xpath("//button[@class='btn blue width-100p ta-c mgb-2']").click()
                print("clicked")
                p["tel"] = browser.find_element_by_xpath("//a[@class='btn blue width-100p ta-c mgb-2']").text
                print("tel saved")
            except NoSuchElementException:
                print("Не нашел кнопку и телефон отдыхает 60 сек")
                q+=1
                if q>6:
                    q=1
                time.sleep(60)
                browser.find_element_by_xpath("//button[@class='btn blue width-100p ta-c mgb-2']").click()
                p["tel"] = browser.find_element_by_xpath("//a[@class='btn blue width-100p ta-c mgb-2']").text
                pass
            except ElementClickInterceptedException:
                print("Не нажал кнопку отдыхает 5 мин")
                q+=1
                if q>6:
                    q=1
                time.sleep(5*60)
                browser.find_element_by_xpath("//button[@class='btn blue width-100p ta-c mgb-2']").click()
                p["tel"] = browser.find_element_by_xpath("//a[@class='btn blue width-100p ta-c mgb-2']").text
                pass
            except TimeoutException:
                print("Не успел нажать кнопку отдыхает 15 сек")
#                 q+=1
#                 if q>3:
#                     q=1
                time.sleep(15)
                browser.find_element_by_xpath("//button[@class='btn blue width-100p ta-c mgb-2']").click()
                p["tel"] = browser.find_element_by_xpath("//a[@class='btn blue width-100p ta-c mgb-2']").text
                pass

        else:
            time.sleep(5*60)
    except NoSuchElementException:
#         q+=1
#         if q>7:
#             q=1
        pass
    except TimeoutException:
#         q+=1
#         if q>7:
#             q=1
        pass
    print("Номер профайла {}".format(i))
    i+=1

end = time.time() - start

print(end)
# Out:
# https://naimi.kz/specialist/242372?service=4  1
# clicked
# Не нашел кнопку и телефон отдыхает 60 сек
# Номер профайла 1
# https://naimi.kz/specialist/177033?service=4  2
# clicked
# Не нашел кнопку и телефон отдыхает 60 сек
# Номер профайла 2
# https://naimi.kz/specialist/180506?service=4  3

# %%
datas
# Out:
# [{'id': '119961',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/119961?service=4',
#   'scraped': 0,
#   'name': 'Екатерина Дерендяева',
#   'age': '41 год',
#   'exp': 'в Naimi.kz 1 год 0 мес.',
#   'price': 'от 5000 тг',
#   'spec_lvl': '4',
#   'review-count': '10',
#   'review-positive': 'width: 90%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 10%;',
#   'edu_prof': 'Нұргүл Көпжасар',
#   'edu_university': None,
#   'tel': '+77789950453'},
#  {'id': '278765',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/278765?service=4',
#   'scraped': 0,
#   'name': 'Талгат Касенов',
#   'age': '23 года',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'от тг',
#   'spec_lvl': '2',
#   'review-count': '1',
#   'review-positive': 'width: 100%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Техник строитель',
#   'edu_university': 'Колледж Инновационного Евразиского Университета, 2',
#   'tel': '+77768184819'},
#  {'id': '250134',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/250134?service=4',
#   'scraped': 0,
#   'name': 'Гульбану Мухамедиева',
#   'age': '38 лет',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'от 7000 тг',
#   'spec_lvl': '3',
#   'review-count': '0',
#   'review-positive': 'width: 0%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Нұргүл Көпжасар',
#   'edu_university': None,
#   'tel': '+77471630910'},
#  {'id': '187126',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/187126?service=4',
#   'scraped': 0,
#   'name': 'Зульфия Давлетьярова',
#   'age': '30 лет',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'от 2000 тг',
#   'spec_lvl': '3',
#   'review-count': '2',
#   'review-positive': 'width: 100%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Финансист',
#   'edu_university': 'ЗКГК, 1',
#   'tel': '+77774077030'},
#  {'id': '113762',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/113762?service=4',
#   'scraped': 0,
#   'name': 'Шакризат Ыскакова',
#   'age': '29 лет',
#   'exp': 'в Naimi.kz 1 год 0 мес.',
#   'price': 'от 10000 тг',
#   'spec_lvl': '11',
#   'review-count': '95',
#   'review-positive': 'width: 91.5789%;',
#   'review-neutral': 'width: 2.10526%;',
#   'review-negative': 'width: 6.31579%;',
#   'edu_prof': 'Юрист',
#   'edu_university': 'М.АУЕЗОВ, 1',
#   'tel': '+77078584326'},
#  {'id': '279371',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/279371?service=4',
#   'scraped': 0,
#   'name': 'Динара Даутахунова',
#   'age': '38 лет',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'от тг',
#   'spec_lvl': '3',
#   'review-count': '4',
#   'review-positive': 'width: 100%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Разнорабочии',
#   'edu_university': 'Средняя шк им Абая, 1',
#   'tel': '+77478976267'},
#  {'id': '95192',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/95192?service=4',
#   'scraped': 0,
#   'name': 'Анастасия Бондарева',
#   'age': '43 года',
#   'exp': 'в Naimi.kz 1 год 0 мес.',
#   'price': 'от 5000 тг',
#   'spec_lvl': '6',
#   'review-count': '25',
#   'review-positive': 'width: 92%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 8%;',
#   'edu_prof': '',
#   'edu_university': 'Каз Гу, 3',
#   'tel': '+77075699132'},
#  {'id': '267322',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/267322?service=4',
#   'scraped': 0,
#   'name': 'Анастасия Кишкина',
#   'age': '34 года',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'от 6000 тг',
#   'spec_lvl': '2',
#   'review-count': '0',
#   'review-positive': 'width: 0%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Мастер маникюра и педикюра',
#   'edu_university': 'Курсы престиж, 1',
#   'tel': '+77052776567'},
#  {'id': '50716',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/50716?service=4',
#   'scraped': 0,
#   'name': 'Эльмира Зурдинова',
#   'age': '33 года',
#   'exp': 'в Naimi.kz 2 года 0 мес.',
#   'price': 'от 6000 тг',
#   'spec_lvl': '8',
#   'review-count': '37',
#   'review-positive': 'width: 91.8919%;',
#   'review-neutral': 'width: 8.10811%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Нұргүл Көпжасар',
#   'edu_university': None,
#   'tel': '+77477258347'},
#  {'id': '269453',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/269453?service=4',
#   'scraped': 0,
#   'name': 'Нургул Кошанова',
#   'age': '23 года',
#   'exp': 'в Naimi.kz недавно',
#   'price': '29 СЕНТЯБРЯ',
#   'spec_lvl': '2',
#   'review-count': '1',
#   'review-positive': 'width: 0%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 100%;',
#   'edu_prof': None,
#   'edu_university': None,
#   'tel': '+77758302897'},
#  {'id': '261199',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/261199?service=4',
#   'scraped': 0,
#   'name': 'Ултуган Акимджанова',
#   'age': '32 года',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'от 6000 тг',
#   'spec_lvl': '2',
#   'review-count': '0',
#   'review-positive': 'width: 0%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Нұргүл Көпжасар',
#   'edu_university': None,
#   'tel': '+77073793887'},
#  {'id': '194264',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/194264?service=4',
#   'scraped': 0,
#   'name': 'Наталья Тозорочева',
#   'age': '38 лет',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'от 6000 тг',
#   'spec_lvl': '9',
#   'review-count': '45',
#   'review-positive': 'width: 95.5556%;',
#   'review-neutral': 'width: 4.44444%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Финансист',
#   'edu_university': 'ТЭК, 2',
#   'tel': '+77754537000'},
#  {'id': '202424',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/202424?service=4',
#   'scraped': 0,
#   'name': 'Мадина Амантай',
#   'age': '22 года',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'от 5000 тг',
#   'spec_lvl': '2',
#   'review-count': '0',
#   'review-positive': 'width: 0%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Нұргүл Көпжасар',
#   'edu_university': None,
#   'tel': '+77073818772'},
#  {'id': '282664',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/282664?service=4',
#   'scraped': 0,
#   'name': 'Александр Попов',
#   'age': '46 лет',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'check',
#   'spec_lvl': '1',
#   'review-count': '0',
#   'review-positive': 'width: 0%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': None,
#   'edu_university': None,
#   'tel': '+77019074062'},
#  {'id': '13737',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/13737?service=4',
#   'scraped': 0,
#   'name': 'Ирина Горелышева',
#   'age': '53 года',
#   'exp': 'в Naimi.kz 4 года 0 мес.',
#   'price': 'от 8000 тг',
#   'spec_lvl': '13',
#   'review-count': '82',
#   'review-positive': 'width: 98.7805%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 1.21951%;',
#   'edu_prof': 'тренер (1984-88)',
#   'edu_university': 'КазИФК, 3',
#   'tel': '+77714904042'},
#  {'id': '229599',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/229599?service=4',
#   'scraped': 0,
#   'name': 'Жаркынай Турсынбаева',
#   'age': '26 лет',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'от 5000 тг',
#   'spec_lvl': '4',
#   'review-count': '9',
#   'review-positive': 'width: 100%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Нұргүл Көпжасар',
#   'edu_university': None,
#   'tel': '+77471066367'},
#  {'id': '283821',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/283821?service=4',
#   'scraped': 0,
#   'name': 'Айдана Халыкбаева',
#   'age': '33 года',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'check',
#   'spec_lvl': '1',
#   'review-count': '0',
#   'review-positive': 'width: 0%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': None,
#   'edu_university': None,
#   'tel': '+77071589187'},
#  {'id': '251496',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/251496?service=4',
#   'scraped': 0,
#   'name': 'Кымбат Дарибаева',
#   'age': '29 лет',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'от 2000 тг',
#   'spec_lvl': '7',
#   'review-count': '26',
#   'review-positive': 'width: 92.3077%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 7.69231%;',
#   'edu_prof': 'Общественный здравахранение',
#   'edu_university': 'Мед академия, 3',
#   'tel': '+77006803260'},
#  {'id': '251063',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/251063?service=4',
#   'scraped': 0,
#   'name': 'Лейла Смаилова',
#   'age': '27 лет',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'от тг',
#   'spec_lvl': '3',
#   'review-count': '2',
#   'review-positive': 'width: 50%;',
#   'review-neutral': 'width: 50%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Нурбек Курбанбаев',
#   'edu_university': None,
#   'tel': '+77071935565'},
#  {'id': '254912',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/254912?service=4',
#   'scraped': 0},
#  {'id': '245275',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/245275?service=4',
#   'scraped': 0,
#   'name': 'Анар Кылышбаева',
#   'age': '32 года',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'от 5000 тг',
#   'spec_lvl': '7',
#   'review-count': '32',
#   'review-positive': 'width: 100%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'картография',
#   'edu_university': 'ГУ имени Шакарима, 3',
#   'tel': '+77027182334'},
#  {'id': '107843',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/107843?service=4',
#   'scraped': 0,
#   'name': 'Азиз Иляхун',
#   'age': '27 лет',
#   'exp': 'в Naimi.kz 1 год 0 мес.',
#   'price': '9 СЕНТЯБРЯ',
#   'spec_lvl': '2',
#   'review-count': '1',
#   'review-positive': 'width: 100%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': None,
#   'edu_university': None,
#   'tel': '+77473616500'},
#  {'id': '105445',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/105445?service=4',
#   'scraped': 0,
#   'name': 'Екатерина Нысанбаева',
#   'age': '38 лет',
#   'exp': 'в Naimi.kz 1 год 0 мес.',
#   'price': 'от 6000 тг',
#   'spec_lvl': '2',
#   'review-count': '2',
#   'review-positive': 'width: 50%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 50%;',
#   'edu_prof': 'Массажист',
#   'edu_university': 'Алматы курсы, 4',
#   'tel': '+77082498318'},
#  {'id': '112806',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/112806?service=4',
#   'scraped': 0,
#   'name': 'Алия Сулеева',
#   'age': '30 лет',
#   'exp': 'в Naimi.kz 1 год 0 мес.',
#   'price': 'от 6000 тг',
#   'spec_lvl': '4',
#   'review-count': '8',
#   'review-positive': 'width: 87.5%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 12.5%;',
#   'edu_prof': 'Педагог',
#   'edu_university': 'ЮКПК, 2',
#   'tel': '+77076920131'},
#  {'id': '63390',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/63390?service=4',
#   'scraped': 0,
#   'name': 'Назгуль Мухадилова',
#   'age': '41 год',
#   'exp': 'в Naimi.kz 2 года 0 мес.',
#   'price': 'от 7000 тг',
#   'spec_lvl': '6',
#   'review-count': '22',
#   'review-positive': 'width: 90.9091%;',
#   'review-neutral': 'width: 4.54545%;',
#   'review-negative': 'width: 4.54545%;',
#   'edu_prof': 'Нұргүл Көпжасар',
#   'edu_university': None,
#   'tel': '+77071570979'},
#  {'id': '133015',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/133015?service=4',
#   'scraped': 0,
#   'name': 'Ботагоз Бірлік',
#   'age': '27 лет',
#   'exp': 'в Naimi.kz 1 год 0 мес.',
#   'price': '7 НОЯБРЯ',
#   'spec_lvl': '4',
#   'review-count': '8',
#   'review-positive': 'width: 100%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': None,
#   'edu_university': None,
#   'tel': '+77073431023'},
#  {'id': '212518',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/212518?service=4',
#   'scraped': 0,
#   'name': 'Лидия Абросимова',
#   'age': '31 год',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'от 4000 тг',
#   'spec_lvl': '3',
#   'review-count': '1',
#   'review-positive': 'width: 100%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Нұргүл Көпжасар',
#   'edu_university': None,
#   'tel': '+77002933570'},
#  {'id': '30002',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/30002?service=4',
#   'scraped': 0,
#   'name': 'Алтынай Жантасова',
#   'age': '25 лет',
#   'exp': 'в Naimi.kz 3 года 0 мес.',
#   'price': 'от 5000 тг',
#   'spec_lvl': '5',
#   'review-count': '15',
#   'review-positive': 'width: 93.3333%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 6.66667%;',
#   'edu_prof': 'Юрист-консультант',
#   'edu_university': 'СГЮК, 2',
#   'tel': '+77000951490'},
#  {'id': '13569',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/13569?service=4',
#   'scraped': 0,
#   'name': 'Анастасия Гилазиева',
#   'age': '36 лет',
#   'exp': 'в Naimi.kz 4 года 0 мес.',
#   'price': 'от 5000 тг',
#   'spec_lvl': '9',
#   'review-count': '53',
#   'review-positive': 'width: 88.6792%;',
#   'review-neutral': 'width: 9.43396%;',
#   'review-negative': 'width: 1.88679%;',
#   'edu_prof': 'Гид агент по туризму',
#   'edu_university': 'Лицей 1, 2',
#   'tel': '+77779632792'},
#  {'id': '119750',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/119750?service=4',
#   'scraped': 0,
#   'name': 'Тамара Мальцева',
#   'age': '44 года',
#   'exp': 'в Naimi.kz 1 год 0 мес.',
#   'price': 'от 5000 тг',
#   'spec_lvl': '2',
#   'review-count': '0',
#   'review-positive': 'width: 0%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Нұргүл Көпжасар',
#   'edu_university': None,
#   'tel': '+77051816399'},
#  {'id': '80429',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/80429?service=4',
#   'scraped': 0,
#   'name': 'Айжан Кусайдарова',
#   'age': '31 год',
#   'exp': 'в Naimi.kz 1 год 0 мес.',
#   'price': 'от 5000 тг',
#   'spec_lvl': '7',
#   'review-count': '24',
#   'review-positive': 'width: 70.8333%;',
#   'review-neutral': 'width: 4.16667%;',
#   'review-negative': 'width: 25%;',
#   'edu_prof': 'Культурология',
#   'edu_university': 'КазНУ им.Аль-фараби, 3',
#   'tel': '+77087272315'},
#  {'id': '282930',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/282930?service=4',
#   'scraped': 0,
#   'name': 'Надия Мухаметкалиева',
#   'age': '39 лет',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'check',
#   'spec_lvl': '1',
#   'review-count': '0',
#   'review-positive': 'width: 0%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': None,
#   'edu_university': None,
#   'tel': '+77758708422'},
#  {'id': '83536',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/83536?service=4',
#   'scraped': 0,
#   'name': 'Асем Мергенбаева',
#   'age': '31 год',
#   'exp': 'в Naimi.kz 1 год 0 мес.',
#   'price': 'от 500 тг',
#   'spec_lvl': '3',
#   'review-count': '0',
#   'review-positive': 'width: 0%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Экономика',
#   'edu_university': 'Юку, 3',
#   'tel': '+77752984944'},
#  {'id': '125990',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/125990?service=4',
#   'scraped': 0,
#   'name': 'Асем Жунисханова',
#   'age': '39 лет',
#   'exp': 'в Naimi.kz 1 год 0 мес.',
#   'price': 'от 5000 тг',
#   'spec_lvl': '4',
#   'review-count': '7',
#   'review-positive': 'width: 85.7143%;',
#   'review-neutral': 'width: 14.2857%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Александра Давлетшина',
#   'edu_university': None,
#   'tel': '+77478452523'},
#  {'id': '128773',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/128773?service=4',
#   'scraped': 0,
#   'name': None,
#   'age': '39 лет',
#   'exp': 'в Naimi.kz 1 год 0 мес.',
#   'price': 'check',
#   'spec_lvl': '1',
#   'review-count': '0',
#   'review-positive': 'width: 0%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': None,
#   'edu_university': None,
#   'tel': '+77079061600'},
#  {'id': '217765',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/217765?service=4',
#   'scraped': 0,
#   'name': 'Динара Шошанова',
#   'age': '31 год',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'от 20000 тг',
#   'spec_lvl': '1',
#   'review-count': '0',
#   'review-positive': 'width: 0%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Эльмира Массимова',
#   'edu_university': None},
#  {'id': '40631',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/40631?service=4',
#   'scraped': 0,
#   'name': 'Оксана Дроздова',
#   'age': '41 год',
#   'exp': 'в Naimi.kz 3 года 0 мес.',
#   'price': 'от тг',
#   'spec_lvl': '2',
#   'review-count': '2',
#   'review-positive': 'width: 100%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Александра Давлетшина',
#   'edu_university': None},
#  {'id': '205352',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/205352?service=4',
#   'scraped': 0,
#   'name': 'Юлия Гречнёва',
#   'age': '31 год',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'от 4000 тг',
#   'spec_lvl': '4',
#   'review-count': '6',
#   'review-positive': 'width: 83.3333%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 16.6667%;',
#   'edu_prof': 'Мастер художник по дизайну',
#   'edu_university': 'Шк 95, 2',
#   'tel': '+77770108620'},
#  {'id': '282851',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/282851?service=4',
#   'scraped': 0,
#   'name': 'Жадыра Калиева',
#   'age': '36 лет',
#   'exp': 'в Naimi.kz недавно',
#   'price': '7 НОЯБРЯ',
#   'spec_lvl': '2',
#   'review-count': '2',
#   'review-positive': 'width: 100%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Повар кондитер',
#   'edu_university': 'А.Т.К(Алматы Технологии Колледже, 2',
#   'tel': '+77771279460'},
#  {'id': '284220',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/284220?service=4',
#   'scraped': 0},
#  {'id': '30204',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/30204?service=4',
#   'scraped': 0,
#   'name': 'Гульнара Аскарбекова',
#   'age': '42 года',
#   'exp': 'в Naimi.kz 3 года 0 мес.',
#   'price': 'от 8000 тг',
#   'spec_lvl': '4',
#   'review-count': '5',
#   'review-positive': 'width: 100%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Менеджер,диспетчер',
#   'edu_university': 'Индустриальный колледж, 2',
#   'tel': '+77088320875'},
#  {'id': '169164',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/169164?service=4',
#   'scraped': 0,
#   'name': 'Динара Кайрова',
#   'age': '39 лет',
#   'exp': 'в Naimi.kz недавно',
#   'price': '12 НОЯБРЯ',
#   'spec_lvl': '3',
#   'review-count': '39',
#   'review-positive': 'width: 79.4872%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 20.5128%;',
#   'edu_prof': None,
#   'edu_university': None,
#   'tel': '+77473863424'},
#  {'id': '73217',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/73217?service=4',
#   'scraped': 0,
#   'name': 'Нургуль Каскабаева',
#   'age': '29 лет',
#   'exp': 'в Naimi.kz 2 года 0 мес.',
#   'price': 'от 5000 тг',
#   'spec_lvl': '2',
#   'review-count': '0',
#   'review-positive': 'width: 0%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': '',
#   'edu_university': 'ЖенПУ, 3',
#   'tel': '+77479783836'},
#  {'id': '271955',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/271955?service=4',
#   'scraped': 0,
#   'name': 'Маржан Кулубекова',
#   'age': '34 года',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'от 5000 тг',
#   'spec_lvl': '2',
#   'review-count': '2',
#   'review-positive': 'width: 100%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Нұргүл Көпжасар',
#   'edu_university': None,
#   'tel': '+77756977424'},
#  {'id': '284253',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/284253?service=4',
#   'scraped': 0,
#   'name': None,
#   'age': '42 года',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'от тг',
#   'spec_lvl': '1',
#   'review-count': '1',
#   'review-positive': 'width: 100%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Нұргүл Көпжасар',
#   'edu_university': None,
#   'tel': '+77076771359'},
#  {'id': '240121',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/240121?service=4',
#   'scraped': 0,
#   'name': None,
#   'age': '48 лет',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'check',
#   'spec_lvl': '1',
#   'review-count': '0',
#   'review-positive': 'width: 0%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': None,
#   'edu_university': None,
#   'tel': '+77074144557'},
#  {'id': '284149',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/284149?service=4',
#   'scraped': 0,
#   'name': 'Балнұр Жанысбек',
#   'age': '25 лет',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'от тг',
#   'spec_lvl': '2',
#   'review-count': '1',
#   'review-positive': 'width: 100%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Нұргүл Көпжасар',
#   'edu_university': None,
#   'tel': '+77756931595'},
#  {'id': '232262',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/232262?service=4',
#   'scraped': 0,
#   'name': 'Ажар Темиржанова',
#   'age': '25 лет',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'от тг',
#   'spec_lvl': '3',
#   'review-count': '5',
#   'review-positive': 'width: 100%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Переводчик',
#   'edu_university': 'Педагогический колледж, 2',
#   'tel': '+77771466901'},
#  {'id': '277235',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/277235?service=4',
#   'scraped': 0,
#   'name': 'Надежда Каминская',
#   'age': '41 год',
#   'exp': 'в Naimi.kz недавно',
#   'price': '31 ОКТЯБРЯ',
#   'spec_lvl': '3',
#   'review-count': '3',
#   'review-positive': 'width: 100%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': None,
#   'edu_university': None,
#   'tel': '+77473802917'},
#  {'id': '206563',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/206563?service=4',
#   'scraped': 0,
#   'name': 'Айгерим Тлеуханова',
#   'age': '26 лет',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'от 5000 тг',
#   'spec_lvl': '5',
#   'review-count': '5',
#   'review-positive': 'width: 100%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Массажист',
#   'edu_university': 'ФМК, 4',
#   'tel': '+77016078356'},
#  {'id': '224289',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/224289?service=4',
#   'scraped': 0,
#   'name': 'Назым Калдыбай',
#   'age': '22 года',
#   'exp': 'в Naimi.kz недавно',
#   'price': '15 НОЯБРЯ',
#   'spec_lvl': '2',
#   'review-count': '1',
#   'review-positive': 'width: 100%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': None,
#   'edu_university': None,
#   'tel': '+77716958679'},
#  {'id': '123862',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/123862?service=4',
#   'scraped': 0,
#   'name': 'Таншолпан Жайлау',
#   'age': '27 лет',
#   'exp': 'в Naimi.kz 1 год 0 мес.',
#   'price': 'от 8000 тг',
#   'spec_lvl': '3',
#   'review-count': '2',
#   'review-positive': 'width: 100%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Нұргүл Көпжасар',
#   'edu_university': None,
#   'tel': '+77006692914'},
#  {'id': '278568',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/278568?service=4',
#   'scraped': 0,
#   'name': 'Жанар Рахметова',
#   'age': '36 лет',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'от тг',
#   'spec_lvl': '2',
#   'review-count': '2',
#   'review-positive': 'width: 50%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 50%;',
#   'edu_prof': 'Криминалистика',
#   'edu_university': 'Академия МВД Караганда, 3',
#   'tel': '+77072090201'},
#  {'id': '281707',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/281707?service=4',
#   'scraped': 0,
#   'name': 'Лаура Аманжолова',
#   'age': '30 лет',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'от тг',
#   'spec_lvl': '3',
#   'review-count': '5',
#   'review-positive': 'width: 80%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 20%;',
#   'edu_prof': 'Техник программист',
#   'edu_university': 'Гумманитарно-технического колледж АСУ, 2',
#   'tel': '+77471960834'},
#  {'id': '40210',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/40210?service=4',
#   'scraped': 0,
#   'name': 'Анастасия Ульмер',
#   'age': '28 лет',
#   'exp': 'в Naimi.kz 3 года 0 мес.',
#   'price': 'от 7000 тг',
#   'spec_lvl': '9',
#   'review-count': '50',
#   'review-positive': 'width: 98%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 2%;',
#   'edu_prof': 'Нұргүл Көпжасар',
#   'edu_university': None,
#   'tel': '+77076376789'},
#  {'id': '267065',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/267065?service=4',
#   'scraped': 0,
#   'name': 'Зульфира Назарбекова',
#   'age': '32 года',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'от 4000 тг',
#   'spec_lvl': '2',
#   'review-count': '0',
#   'review-positive': 'width: 0%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Фармацевт',
#   'edu_university': 'Колледж, 3'},
#  {'id': '79737',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/79737?service=4',
#   'scraped': 0,
#   'name': 'Бота Кибраева',
#   'age': '30 лет',
#   'exp': 'в Naimi.kz 1 год 0 мес.',
#   'price': 'от 5000 тг',
#   'spec_lvl': '2',
#   'review-count': '0',
#   'review-positive': 'width: 0%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Нұргүл Көпжасар',
#   'edu_university': None,
#   'tel': '+77477022792'},
#  {'id': '157584',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/157584?service=4',
#   'scraped': 0,
#   'name': 'Мадина Исмайлова',
#   'age': '39 лет',
#   'exp': 'в Naimi.kz 1 год 0 мес.',
#   'price': 'от 1200 тг',
#   'spec_lvl': '7',
#   'review-count': '19',
#   'review-positive': 'width: 78.9474%;',
#   'review-neutral': 'width: 5.26316%;',
#   'review-negative': 'width: 15.7895%;',
#   'edu_prof': 'Данияр Турысбеков',
#   'edu_university': None},
#  {'id': '238196',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/238196?service=4',
#   'scraped': 0,
#   'name': 'Анара Думчебаева',
#   'age': '38 лет',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'check',
#   'spec_lvl': '1',
#   'review-count': '0',
#   'review-positive': 'width: 0%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': None,
#   'edu_university': None,
#   'tel': '+77777369988'},
#  {'id': '125481',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/125481?service=4',
#   'scraped': 0},
#  {'id': '270244',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/270244?service=4',
#   'scraped': 0,
#   'name': None,
#   'age': '34 года',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'check',
#   'spec_lvl': '1',
#   'review-count': '0',
#   'review-positive': 'width: 0%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': None,
#   'edu_university': None,
#   'tel': '+77078648285'},
#  {'id': '263060',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/263060?service=4',
#   'scraped': 0,
#   'name': 'Роза Омурбаева',
#   'age': '40 лет',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'от 10000 тг',
#   'spec_lvl': '4',
#   'review-count': '7',
#   'review-positive': 'width: 100%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Переводчик',
#   'edu_university': 'Кайнар, 3',
#   'tel': '+77778466960'},
#  {'id': '123942',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/123942?service=4',
#   'scraped': 0,
#   'name': 'Акмарал Мырзабек',
#   'age': '25 лет',
#   'exp': 'в Naimi.kz 1 год 0 мес.',
#   'price': 'от тг',
#   'spec_lvl': '3',
#   'review-count': '4',
#   'review-positive': 'width: 75%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 25%;',
#   'edu_prof': 'Швея',
#   'edu_university': 'Школа 20, 1',
#   'tel': '+77077909225'},
#  {'id': '226671',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/226671?service=4',
#   'scraped': 0,
#   'name': 'Анар Толегенова',
#   'age': '43 года',
#   'exp': 'в Naimi.kz недавно',
#   'price': '15 СЕНТЯБРЯ',
#   'spec_lvl': '3',
#   'review-count': '3',
#   'review-positive': 'width: 66.6667%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 33.3333%;',
#   'edu_prof': None,
#   'edu_university': None,
#   'tel': '+77021488824'},
#  {'id': '158145',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/158145?service=4',
#   'scraped': 0,
#   'name': 'Марфуга Нургалиева',
#   'age': '25 лет',
#   'exp': 'в Naimi.kz 1 год 0 мес.',
#   'price': '11 НОЯБРЯ',
#   'spec_lvl': '4',
#   'review-count': '9',
#   'review-positive': 'width: 100%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': None,
#   'edu_university': None,
#   'tel': '+77771256660'},
#  {'id': '277014',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/277014?service=4',
#   'scraped': 0,
#   'name': 'Амантай Бердхан',
#   'age': '32 года',
#   'exp': 'в Naimi.kz недавно',
#   'price': '2 НОЯБРЯ',
#   'spec_lvl': '2',
#   'review-count': '3',
#   'review-positive': 'width: 100%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': None,
#   'edu_university': None,
#   'tel': '+77771300009'},
#  {'id': '15882',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/15882?service=4',
#   'scraped': 0,
#   'name': 'Маргарита Микрюкова',
#   'age': '29 лет',
#   'exp': 'в Naimi.kz 3 года 0 мес.',
#   'price': 'от 5000 тг',
#   'spec_lvl': '8',
#   'review-count': '39',
#   'review-positive': 'width: 97.4359%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 2.5641%;',
#   'edu_prof': 'Нұргүл Көпжасар',
#   'edu_university': None,
#   'tel': '+77784443640'},
#  {'id': '199247',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/199247?service=4',
#   'scraped': 0,
#   'name': None,
#   'age': '29 лет',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'от 2000 тг',
#   'spec_lvl': '1',
#   'review-count': '0',
#   'review-positive': 'width: 0%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Менеджер по обслуживанию гостиничных комплексов и турфирм',
#   'edu_university': 'Академия спорта и туризма, 3',
#   'tel': '+77077332203'},
#  {'id': '123529',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/123529?service=4',
#   'scraped': 0,
#   'name': 'Асель Жайлаубай',
#   'age': '26 лет',
#   'exp': 'в Naimi.kz 1 год 0 мес.',
#   'price': 'от 35000 тг',
#   'spec_lvl': '4',
#   'review-count': '10',
#   'review-positive': 'width: 80%;',
#   'review-neutral': 'width: 10%;',
#   'review-negative': 'width: 10%;',
#   'edu_prof': 'Саида Мусаева',
#   'edu_university': None,
#   'tel': '+77472712316'},
#  {'id': '238271',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/238271?service=4',
#   'scraped': 0,
#   'name': None,
#   'age': '19 лет',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'check',
#   'spec_lvl': '1',
#   'review-count': '0',
#   'review-positive': 'width: 0%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': None,
#   'edu_university': None,
#   'tel': '+77088489326'},
#  {'id': '156852',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/156852?service=4',
#   'scraped': 0,
#   'name': 'Айдана Абишева',
#   'age': '25 лет',
#   'exp': 'в Naimi.kz 1 год 0 мес.',
#   'price': 'от 5000 тг',
#   'spec_lvl': '5',
#   'review-count': '11',
#   'review-positive': 'width: 100%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Специалист по уборке',
#   'edu_university': 'Средняя школа имени Копбаева, 1',
#   'tel': '+77771426517'},
#  {'id': '55214',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/55214?service=4',
#   'scraped': 0,
#   'name': 'Камила Юлдашева',
#   'age': '30 лет',
#   'exp': 'в Naimi.kz 2 года 0 мес.',
#   'price': 'от 5000 тг',
#   'spec_lvl': '9',
#   'review-count': '56',
#   'review-positive': 'width: 91.0714%;',
#   'review-neutral': 'width: 5.35714%;',
#   'review-negative': 'width: 3.57143%;',
#   'edu_prof': 'Переводчик-референт',
#   'edu_university': 'Алматинский колледж Менеджмента и маркетинга, 1',
#   'tel': '+77057219446'},
#  {'id': '201637',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/201637?service=4',
#   'scraped': 0,
#   'name': 'Елена Шорина',
#   'age': '55 лет',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'от 500 тг',
#   'spec_lvl': '3',
#   'review-count': '4',
#   'review-positive': 'width: 100%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Филолог',
#   'edu_university': 'КазПИ им Абая, 3',
#   'tel': '+77770208928'},
#  {'id': '235532',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/235532?service=4',
#   'scraped': 0,
#   'name': 'Сымбат Кулжабаева',
#   'age': '32 года',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'от 5000 тг',
#   'spec_lvl': '2',
#   'review-count': '0',
#   'review-positive': 'width: 0%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Мт',
#   'edu_university': 'Акнт, 2'},
#  {'id': '27549',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/27549?service=4',
#   'scraped': 0,
#   'name': 'Асылзат Камбарбекова',
#   'age': '33 года',
#   'exp': 'в Naimi.kz 3 года 0 мес.',
#   'price': 'от 5000 тг',
#   'spec_lvl': '10',
#   'review-count': '51',
#   'review-positive': 'width: 100%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Нұргүл Көпжасар',
#   'edu_university': None,
#   'tel': '+77072629942'},
#  {'id': '111974',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/111974?service=4',
#   'scraped': 0,
#   'name': 'Алексей Ковалёв',
#   'age': '23 года',
#   'exp': 'в Naimi.kz 1 год 0 мес.',
#   'price': 'от 5500 тг',
#   'spec_lvl': '2',
#   'review-count': '1',
#   'review-positive': 'width: 100%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Режиссёр',
#   'edu_university': 'Колледж культуры, 2',
#   'tel': '+77074826102'},
#  {'id': '249131',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/249131?service=4',
#   'scraped': 0,
#   'name': 'Кымбат Жунусбекова',
#   'age': '42 года',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'от 3000 тг',
#   'spec_lvl': '4',
#   'review-count': '7',
#   'review-positive': 'width: 100%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Нұргүл Көпжасар',
#   'edu_university': None},
#  {'id': '100072',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/100072?service=4',
#   'scraped': 0,
#   'name': None,
#   'age': '43 года',
#   'exp': 'в Naimi.kz 1 год 0 мес.',
#   'price': 'check',
#   'spec_lvl': '1',
#   'review-count': '0',
#   'review-positive': 'width: 0%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': None,
#   'edu_university': None},
#  {'id': '268068',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/268068?service=4',
#   'scraped': 0,
#   'name': 'Наталья Смагулова',
#   'age': '40 лет',
#   'exp': 'в Naimi.kz недавно',
#   'price': '27 СЕНТЯБРЯ',
#   'spec_lvl': '2',
#   'review-count': '3',
#   'review-positive': 'width: 100%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Экономист',
#   'edu_university': 'Центрально Азиатский Университет, 3',
#   'tel': '+77081903040'},
#  {'id': '273223',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/273223?service=4',
#   'scraped': 0},
#  {'id': '240676',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/240676?service=4',
#   'scraped': 0,
#   'name': 'Эленора Сапакова',
#   'age': '33 года',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'от тг',
#   'spec_lvl': '2',
#   'review-count': '0',
#   'review-positive': 'width: 0%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Нұргүл Көпжасар',
#   'edu_university': None,
#   'tel': '+77073934963'},
#  {'id': '272689',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/272689?service=4',
#   'scraped': 0,
#   'name': 'Зауре Рустамова',
#   'age': '27 лет',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'check',
#   'spec_lvl': '1',
#   'review-count': '0',
#   'review-positive': 'width: 0%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': None,
#   'edu_university': None,
#   'tel': '+77478392104'},
#  {'id': '283117',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/283117?service=4',
#   'scraped': 0,
#   'name': 'Айнура Махамбетова',
#   'age': '31 год',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'check',
#   'spec_lvl': '1',
#   'review-count': '0',
#   'review-positive': 'width: 0%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': None,
#   'edu_university': None,
#   'tel': '+77771409893'},
#  {'id': '175123',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/175123?service=4',
#   'scraped': 0,
#   'name': 'Лаура Есимханова',
#   'age': '35 лет',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'от 5000 тг',
#   'spec_lvl': '2',
#   'review-count': '0',
#   'review-positive': 'width: 0%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Нұргүл Көпжасар',
#   'edu_university': None,
#   'tel': '+77073684171'},
#  {'id': '222821',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/222821?service=4',
#   'scraped': 0,
#   'name': 'Нургул Серікбаева',
#   'age': '30 лет',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'от 4000 тг',
#   'spec_lvl': '2',
#   'review-count': '2',
#   'review-positive': 'width: 100%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Нұргүл Көпжасар',
#   'edu_university': None,
#   'tel': '+77075830921'},
#  {'id': '199958',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/199958?service=4',
#   'scraped': 0,
#   'name': 'Павел Петрушенко',
#   'age': '37 лет',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'от 2000 тг',
#   'spec_lvl': '2',
#   'review-count': '2',
#   'review-positive': 'width: 50%;',
#   'review-neutral': 'width: 50%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Слесарь сборщик',
#   'edu_university': 'Школа32, 2',
#   'tel': '+77051848125'},
#  {'id': '85961',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/85961?service=4',
#   'scraped': 0,
#   'name': 'Акмарал Артыкбаева',
#   'age': '31 год',
#   'exp': 'в Naimi.kz 1 год 0 мес.',
#   'price': 'от 6000 тг',
#   'spec_lvl': '2',
#   'review-count': '0',
#   'review-positive': 'width: 0%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Нұргүл Көпжасар',
#   'edu_university': None,
#   'tel': '+77783157070'},
#  {'id': '138999',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/138999?service=4',
#   'scraped': 0,
#   'name': 'Динара Абдразакова',
#   'age': '41 год',
#   'exp': 'в Naimi.kz 1 год 0 мес.',
#   'price': 'от 3000 тг',
#   'spec_lvl': '2',
#   'review-count': '2',
#   'review-positive': 'width: 50%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 50%;',
#   'edu_prof': 'Педагог',
#   'edu_university': 'КазГУ, 3',
#   'tel': '+77004044704'},
#  {'id': '222613',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/222613?service=4',
#   'scraped': 0,
#   'name': 'Гаухар Асанбекова',
#   'age': '47 лет',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'check',
#   'spec_lvl': '2',
#   'review-count': '0',
#   'review-positive': 'width: 0%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': None,
#   'edu_university': None,
#   'tel': '+77085959083'},
#  {'id': '137396',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/137396?service=4',
#   'scraped': 0,
#   'name': 'Ақбота Серікқызы',
#   'age': '22 года',
#   'exp': 'в Naimi.kz 1 год 0 мес.',
#   'price': '15 НОЯБРЯ',
#   'spec_lvl': '3',
#   'review-count': '5',
#   'review-positive': 'width: 80%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 20%;',
#   'edu_prof': 'Кройка шитье',
#   'edu_university': 'Лицей 2, 2',
#   'tel': '+77473669480'},
#  {'id': '195636',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/195636?service=4',
#   'scraped': 0,
#   'name': 'Акмарал Айтжан',
#   'age': '22 года',
#   'exp': 'в Naimi.kz недавно',
#   'price': '2 АВГУСТА',
#   'spec_lvl': '1',
#   'review-count': '4',
#   'review-positive': 'width: 50%;',
#   'review-neutral': 'width: 25%;',
#   'review-negative': 'width: 25%;',
#   'edu_prof': None,
#   'edu_university': None,
#   'tel': '+77474603043'},
#  {'id': '58867',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/58867?service=4',
#   'scraped': 0,
#   'name': 'Бекжан Ибраимов',
#   'age': '33 года',
#   'exp': 'в Naimi.kz 2 года 0 мес.',
#   'price': 'от тг',
#   'spec_lvl': '2',
#   'review-count': '0',
#   'review-positive': 'width: 0%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'связист',
#   'edu_university': 'Институт связи, 3',
#   'tel': '+77714087709'},
#  {'id': '221108',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/221108?service=4',
#   'scraped': 0,
#   'name': 'Нұрилаш Сапарәлі',
#   'age': '25 лет',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'от тг',
#   'spec_lvl': '2',
#   'review-count': '5',
#   'review-positive': 'width: 60%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 40%;',
#   'edu_prof': 'Нұргүл Көпжасар',
#   'edu_university': None,
#   'tel': '+77472710399'},
#  {'id': '143369',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/143369?service=4',
#   'scraped': 0,
#   'name': 'Асем Давлетова',
#   'age': '23 года',
#   'exp': 'в Naimi.kz 1 год 0 мес.',
#   'price': 'от 6000 тг',
#   'spec_lvl': '3',
#   'review-count': '4',
#   'review-positive': 'width: 100%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Финансист',
#   'edu_university': 'Колледж Экономики и Финансов, 2'},
#  {'id': '282460',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/282460?service=4',
#   'scraped': 0,
#   'name': None,
#   'age': '40 лет',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'check',
#   'spec_lvl': '1',
#   'review-count': '0',
#   'review-positive': 'width: 0%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': None,
#   'edu_university': None,
#   'tel': '+77077185891'},
#  {'id': '265246',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/265246?service=4',
#   'scraped': 0,
#   'name': 'Андрей Лукашевский',
#   'age': '42 года',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'от 250000 тг',
#   'spec_lvl': '2',
#   'review-count': '1',
#   'review-positive': 'width: 100%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Телеоператор',
#   'edu_university': 'Интерньюс - Казахстан, 4'},
#  {'id': '156068',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/156068?service=4',
#   'scraped': 0,
#   'name': 'Дамира Баймырзаева',
#   'age': '32 года',
#   'exp': 'в Naimi.kz 1 год 0 мес.',
#   'price': 'от 5000 тг',
#   'spec_lvl': '3',
#   'review-count': '7',
#   'review-positive': 'width: 71.4286%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 28.5714%;',
#   'edu_prof': 'Биолоия',
#   'edu_university': 'ТИГУ, 3'},
#  {'id': '56709',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/56709?service=4',
#   'scraped': 0,
#   'name': 'Лаура Кейтенова',
#   'age': '35 лет',
#   'exp': 'в Naimi.kz 2 года 0 мес.',
#   'price': 'от 5000 тг',
#   'spec_lvl': '2',
#   'review-count': '3',
#   'review-positive': 'width: 100%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Улмекен Сабденбекова',
#   'edu_university': None,
#   'tel': '+77472478606'},
#  {'id': '270776',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/270776?service=4',
#   'scraped': 0,
#   'name': 'Нұрғали Қожанов',
#   'age': '29 лет',
#   'exp': 'в Naimi.kz недавно',
#   'price': '16 ОКТЯБРЯ',
#   'spec_lvl': '3',
#   'review-count': '3',
#   'review-positive': 'width: 100%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': None,
#   'edu_university': None,
#   'tel': '+77479810076'},
#  {'id': '163092',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/163092?service=4',
#   'scraped': 0},
#  {'id': '254424',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/254424?service=4',
#   'scraped': 0,
#   'name': 'Ботагоз Тлеубаева',
#   'age': '38 лет',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'от тг',
#   'spec_lvl': '4',
#   'review-count': '12',
#   'review-positive': 'width: 100%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Бухгалтер',
#   'edu_university': 'Центральный дом бухгалтера, 4',
#   'tel': '+77077797237'},
#  {'id': '265396',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/265396?service=4',
#   'scraped': 0,
#   'name': 'Наргиза Тохтиева',
#   'age': '37 лет',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'check',
#   'spec_lvl': '1',
#   'review-count': '0',
#   'review-positive': 'width: 0%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': None,
#   'edu_university': None,
#   'tel': '+77473599897'},
#  {'id': '233842',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/233842?service=4',
#   'scraped': 0,
#   'name': 'Гаухар Манибаева',
#   'age': '34 года',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'check',
#   'spec_lvl': '1',
#   'review-count': '0',
#   'review-positive': 'width: 0%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': None,
#   'edu_university': None,
#   'tel': '+77085018682'},
#  {'id': '206901',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/206901?service=4',
#   'scraped': 0,
#   'name': 'Бибиойша Бекбенбетова',
#   'age': '22 года',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'от 4000 тг',
#   'spec_lvl': '7',
#   'review-count': '33',
#   'review-positive': 'width: 90.9091%;',
#   'review-neutral': 'width: 3.0303%;',
#   'review-negative': 'width: 6.06061%;',
#   'edu_prof': '',
#   'edu_university': 'Школа №77, 1',
#   'tel': '+77783211359'},
#  {'id': '281924',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/281924?service=4',
#   'scraped': 0,
#   'name': 'Арайлым Муканова',
#   'age': '24 года',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'check',
#   'spec_lvl': '1',
#   'review-count': '0',
#   'review-positive': 'width: 0%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Переводчик китайского языка',
#   'edu_university': 'Казахско китайская академия, 2',
#   'tel': '+77472000896'},
#  {'id': '281998',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/281998?service=4',
#   'scraped': 0,
#   'name': 'Жадыра Нусип',
#   'age': '18 лет',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'от тг',
#   'spec_lvl': '1',
#   'review-count': '0',
#   'review-positive': 'width: 0%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'Улмекен Сабденбекова',
#   'edu_university': None,
#   'tel': '+77071520027'},
#  {'id': '251969',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/251969?service=4',
#   'scraped': 0,
#   'name': 'Гүлсезім Балғабек',
#   'age': '18 лет',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'от 6000 тг',
#   'spec_lvl': '3',
#   'review-count': '16',
#   'review-positive': 'width: 81.25%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 18.75%;',
#   'edu_prof': 'Акушер',
#   'edu_university': 'Школа 27, 3',
#   'tel': '+77773856587'},
#  {'id': '211958',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/211958?service=4',
#   'scraped': 0,
#   'name': 'Айгуль Айбосынова',
#   'age': '44 года',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'check',
#   'spec_lvl': '2',
#   'review-count': '0',
#   'review-positive': 'width: 0%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': None,
#   'edu_university': None,
#   'tel': '+77073529531'},
#  {'id': '243218',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/243218?service=4',
#   'scraped': 0,
#   'name': 'Аяулым Уатаева',
#   'age': '26 лет',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'check',
#   'spec_lvl': '2',
#   'review-count': '0',
#   'review-positive': 'width: 0%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': None,
#   'edu_university': None,
#   'tel': '+77088025488'},
#  {'id': '231426',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/231426?service=4',
#   'scraped': 0,
#   'name': 'Алтынай Искандарова',
#   'age': '44 года',
#   'exp': 'в Naimi.kz недавно',
#   'price': 'check',
#   'spec_lvl': '2',
#   'review-count': '0',
#   'review-positive': 'width: 0%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': None,
#   'edu_university': None,
#   'tel': '+77785670828'},
#  {'id': '159861',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/159861?service=4',
#   'scraped': 0,
#   'name': 'Зейнегуль Таубаева',
#   'age': '44 года',
#   'exp': 'в Naimi.kz 1 год 0 мес.',
#   'price': 'от тг',
#   'spec_lvl': '1',
#   'review-count': '0',
#   'review-positive': 'width: 0%;',
#   'review-neutral': 'width: 0%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': 'дизайнер и педагог дошкол.обр',
#   'edu_university': 'ПРОФ.ТЕХ.УЧИЛИЩЕ -7, 2',
#   'tel': '+77077447016'},
#  {'id': '282327',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/282327?service=4',
#   'scraped': 0,
# ...
#  {'id': '235913',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/235913?service=4',
#   'scraped': 0},
#  {'id': '235935',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/235935?service=4',
#   'scraped': 0},
#  {'id': '236024',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/236024?service=4',
#   'scraped': 0},
#  {'id': '236137',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/236137?service=4',
#   'scraped': 0},
#  {'id': '236153',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/236153?service=4',
#   'scraped': 0},
#  {'id': '236205',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/236205?service=4',
#   'scraped': 0},
#  {'id': '236207',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/236207?service=4',
#   'scraped': 0},
#  {'id': '236273',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/236273?service=4',
#   'scraped': 0},
#  {'id': '236321',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/236321?service=4',
#   'scraped': 0},
#  {'id': '236455',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/236455?service=4',
#   'scraped': 0},
#  {'id': '236645',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/236645?service=4',
#   'scraped': 0},
#  {'id': '236703',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/236703?service=4',
#   'scraped': 0},
#  {'id': '236763',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/236763?service=4',
#   'scraped': 0},
#  {'id': '236769',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/236769?service=4',
#   'scraped': 0},
#  {'id': '236979',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/236979?service=4',
#   'scraped': 0},
#  {'id': '237018',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/237018?service=4',
#   'scraped': 0},
#  {'id': '237075',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/237075?service=4',
#   'scraped': 0},
#  {'id': '237089',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/237089?service=4',
#   'scraped': 0},
#  {'id': '237194',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/237194?service=4',
#   'scraped': 0},
#  {'id': '237254',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/237254?service=4',
#   'scraped': 0},
#  {'id': '237260',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/237260?service=4',
#   'scraped': 0},
#  {'id': '237309',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/237309?service=4',
#   'scraped': 0},
#  {'id': '237319',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/237319?service=4',
#   'scraped': 0},
#  {'id': '237426',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/237426?service=4',
#   'scraped': 0},
#  {'id': '237435',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/237435?service=4',
#   'scraped': 0},
#  {'id': '237437',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/237437?service=4',
#   'scraped': 0},
#  {'id': '237468',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/237468?service=4',
#   'scraped': 0},
#  {'id': '237484',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/237484?service=4',
#   'scraped': 0},
#  {'id': '237501',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/237501?service=4',
#   'scraped': 0},
#  {'id': '237591',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/237591?service=4',
#   'scraped': 0},
#  {'id': '237620',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/237620?service=4',
#   'scraped': 0},
#  {'id': '237628',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/237628?service=4',
#   'scraped': 0},
#  {'id': '237687',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/237687?service=4',
#   'scraped': 0},
#  {'id': '237738',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/237738?service=4',
#   'scraped': 0},
#  {'id': '237797',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/237797?service=4',
#   'scraped': 0},
#  {'id': '237866',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/237866?service=4',
#   'scraped': 0},
#  {'id': '237870',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/237870?service=4',
#   'scraped': 0},
#  {'id': '237914',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/237914?service=4',
#   'scraped': 0},
#  {'id': '237937',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/237937?service=4',
#   'scraped': 0},
#  {'id': '237960',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/237960?service=4',
#   'scraped': 0},
#  {'id': '237974',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/237974?service=4',
#   'scraped': 0},
#  {'id': '238159',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/238159?service=4',
#   'scraped': 0},
#  {'id': '238176',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/238176?service=4',
#   'scraped': 0},
#  {'id': '238207',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/238207?service=4',
#   'scraped': 0},
#  {'id': '238209',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/238209?service=4',
#   'scraped': 0},
#  {'id': '238237',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/238237?service=4',
#   'scraped': 0},
#  {'id': '238275',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/238275?service=4',
#   'scraped': 0},
#  {'id': '238425',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/238425?service=4',
#   'scraped': 0},
#  {'id': '238435',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/238435?service=4',
#   'scraped': 0},
#  {'id': '238586',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/238586?service=4',
#   'scraped': 0},
#  {'id': '238640',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/238640?service=4',
#   'scraped': 0},
#  {'id': '238683',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/238683?service=4',
#   'scraped': 0},
#  {'id': '238724',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/238724?service=4',
#   'scraped': 0},
#  {'id': '238786',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/238786?service=4',
#   'scraped': 0},
#  {'id': '238814',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/238814?service=4',
#   'scraped': 0},
#  {'id': '238843',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/238843?service=4',
#   'scraped': 0},
#  {'id': '238844',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/238844?service=4',
#   'scraped': 0},
#  {'id': '238879',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/238879?service=4',
#   'scraped': 0},
#  {'id': '238924',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/238924?service=4',
#   'scraped': 0},
#  {'id': '238936',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/238936?service=4',
#   'scraped': 0},
#  {'id': '238986',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/238986?service=4',
#   'scraped': 0},
#  {'id': '238990',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/238990?service=4',
#   'scraped': 0},
#  {'id': '238998',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/238998?service=4',
#   'scraped': 0},
#  {'id': '239016',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/239016?service=4',
#   'scraped': 0},
#  {'id': '239053',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/239053?service=4',
#   'scraped': 0},
#  {'id': '239070',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/239070?service=4',
#   'scraped': 0},
#  {'id': '239150',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/239150?service=4',
#   'scraped': 0},
#  {'id': '239188',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/239188?service=4',
#   'scraped': 0},
#  {'id': '239323',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/239323?service=4',
#   'scraped': 0},
#  {'id': '239411',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/239411?service=4',
#   'scraped': 0},
#  {'id': '239447',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/239447?service=4',
#   'scraped': 0},
#  {'id': '239448',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/239448?service=4',
#   'scraped': 0},
#  {'id': '239473',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/239473?service=4',
#   'scraped': 0},
#  {'id': '239474',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/239474?service=4',
#   'scraped': 0},
#  {'id': '239518',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/239518?service=4',
#   'scraped': 0},
#  {'id': '239578',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/239578?service=4',
#   'scraped': 0},
#  {'id': '239625',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/239625?service=4',
#   'scraped': 0},
#  {'id': '239631',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/239631?service=4',
#   'scraped': 0},
#  {'id': '239670',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/239670?service=4',
#   'scraped': 0},
#  {'id': '239683',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/239683?service=4',
#   'scraped': 0},
#  {'id': '239795',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/239795?service=4',
#   'scraped': 0},
#  {'id': '239852',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/239852?service=4',
#   'scraped': 0},
#  {'id': '239888',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/239888?service=4',
#   'scraped': 0},
#  {'id': '239919',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/239919?service=4',
#   'scraped': 0},
#  {'id': '239931',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/239931?service=4',
#   'scraped': 0},
#  {'id': '239947',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/239947?service=4',
#   'scraped': 0},
#  {'id': '239956',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/239956?service=4',
#   'scraped': 0},
#  {'id': '239988',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/239988?service=4',
#   'scraped': 0},
#  {'id': '240026',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/240026?service=4',
#   'scraped': 0},
#  {'id': '240251',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/240251?service=4',
#   'scraped': 0},
#  {'id': '240267',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/240267?service=4',
#   'scraped': 0},
#  {'id': '240276',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/240276?service=4',
#   'scraped': 0},
#  {'id': '240346',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/240346?service=4',
#   'scraped': 0},
#  {'id': '240361',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/240361?service=4',
#   'scraped': 0},
#  {'id': '240396',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/240396?service=4',
#   'scraped': 0},
#  {'id': '240397',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/240397?service=4',
#   'scraped': 0},
#  {'id': '240556',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/240556?service=4',
#   'scraped': 0},
#  {'id': '240565',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/240565?service=4',
#   'scraped': 0},
#  {'id': '240680',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/240680?service=4',
#   'scraped': 0},
#  {'id': '240723',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/240723?service=4',
#   'scraped': 0},
#  {'id': '240745',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/240745?service=4',
#   'scraped': 0},
#  {'id': '240783',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/240783?service=4',
#   'scraped': 0},
#  {'id': '240832',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/240832?service=4',
#   'scraped': 0},
#  {'id': '240943',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/240943?service=4',
#   'scraped': 0},
#  {'id': '241036',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/241036?service=4',
#   'scraped': 0},
#  {'id': '241095',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/241095?service=4',
#   'scraped': 0},
#  {'id': '241130',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/241130?service=4',
#   'scraped': 0},
#  {'id': '241205',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/241205?service=4',
#   'scraped': 0},
#  {'id': '241263',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/241263?service=4',
#   'scraped': 0},
#  {'id': '241381',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/241381?service=4',
#   'scraped': 0},
#  {'id': '241499',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/241499?service=4',
#   'scraped': 0},
#  {'id': '241556',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/241556?service=4',
#   'scraped': 0},
#  {'id': '241618',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/241618?service=4',
#   'scraped': 0},
#  {'id': '241620',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/241620?service=4',
#   'scraped': 0},
#  {'id': '241698',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/241698?service=4',
#   'scraped': 0},
#  {'id': '241719',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/241719?service=4',
#   'scraped': 0},
#  {'id': '241770',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/241770?service=4',
#   'scraped': 0},
#  {'id': '241790',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/241790?service=4',
#   'scraped': 0},
#  {'id': '241799',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/241799?service=4',
#   'scraped': 0},
#  {'id': '241974',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/241974?service=4',
#   'scraped': 0},
#  {'id': '242075',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/242075?service=4',
#   'scraped': 0},
#  {'id': '242076',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/242076?service=4',
#   'scraped': 0},
#  {'id': '242096',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/242096?service=4',
#   'scraped': 0},
#  {'id': '242371',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/242371?service=4',
#   'scraped': 0},
#  {'id': '242437',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/242437?service=4',
#   'scraped': 0},
#  {'id': '242449',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/242449?service=4',
#   'scraped': 0},
#  {'id': '242474',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/242474?service=4',
#   'scraped': 0},
#  {'id': '242498',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/242498?service=4',
#   'scraped': 0},
#  {'id': '242568',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/242568?service=4',
#   'scraped': 0},
#  {'id': '242589',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/242589?service=4',
#   'scraped': 0},
#  {'id': '242682',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/242682?service=4',
#   'scraped': 0},
#  {'id': '242754',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/242754?service=4',
#   'scraped': 0},
#  {'id': '242899',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/242899?service=4',
#   'scraped': 0},
#  {'id': '242948',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/242948?service=4',
#   'scraped': 0},
#  {'id': '242961',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/242961?service=4',
#   'scraped': 0},
#  {'id': '243015',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/243015?service=4',
#   'scraped': 0},
#  {'id': '243035',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/243035?service=4',
#   'scraped': 0},
#  {'id': '243053',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/243053?service=4',
#   'scraped': 0},
#  {'id': '243099',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/243099?service=4',
#   'scraped': 0},
#  {'id': '243124',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/243124?service=4',
#   'scraped': 0},
#  {'id': '243213',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/243213?service=4',
#   'scraped': 0},
#  {'id': '243279',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/243279?service=4',
#   'scraped': 0},
#  {'id': '243399',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/243399?service=4',
#   'scraped': 0},
#  {'id': '243458',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/243458?service=4',
#   'scraped': 0},
#  {'id': '243498',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/243498?service=4',
#   'scraped': 0},
#  {'id': '243626',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/243626?service=4',
#   'scraped': 0},
#  {'id': '243660',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/243660?service=4',
#   'scraped': 0},
#  {'id': '243697',
#   'slug': '4',
#   'path': 'https://naimi.kz/specialist/243697?service=4',
#   'scraped': 0},
#  ...]

# %%
# newDict = list()

# %%
len(newDict_done)
# Out:
# 189

# %%
# _done=list()

# %%
# Iterate over all the items in dictionary and filter items which has even keys
for i in not_done:
    if i.get('tel',None)!=None:
        _done.append(i)
print('Filtered Dictionary : ')
len(_done)
# Out:
# Filtered Dictionary :
# 301

# %%
# Iterate over all the items in dictionary and filter items which has even keys
for i in datas2:
    if i.get('tel',None)!=None:
        _done.append(i)
print('Filtered Dictionary : ')
len(_done)
# Out:
# Filtered Dictionary :
# 283

# %%
not_done=list()
for i in datas2:
    if i.get('path') not in [x.get('path') for x in _done]:
        not_done.append(i)
    else:
        pass

# %%
len(datas2)
# Out:
# 16033

# %%
len(not_done)
# Out:
# 15779

# %%
df=pd.DataFrame(_done)

# %%
with open(r'_done.pickle', 'wb') as output:
    pickle.dump(_done, output)

# %%
df['tel'].nunique()
# Out:
# 236

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 283 entries, 0 to 282
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               283 non-null    object
#  1   slug             283 non-null    object
#  2   path             283 non-null    object
#  3   scraped          283 non-null    int64
#  4   name             261 non-null    object
#  5   age              283 non-null    object
#  6   exp              283 non-null    object
#  7   price            283 non-null    object
#  8   spec_lvl         283 non-null    object
#  9   review-count     283 non-null    object
#  10  review-positive  283 non-null    object
#  11  review-neutral   283 non-null    object
#  12  review-negative  283 non-null    object
#  13  edu_prof         209 non-null    object
#  14  edu_university   140 non-null    object
#  15  tel              283 non-null    object
# dtypes: int64(1), object(15)
# memory usage: 35.5+ KB

# %%
df['age_int']=df['age'].map(lambda x: x.rstrip(' лет года')).astype(int)

# %%
df['age_int'].mean()
# Out:
# 33.0

# %%
newDict_done = list()
# Iterate over all the items in dictionary and filter items which has even keys
for i in datas:
    if i.get('tel',None)!=None:
        newDict_done.append(i)
print('Filtered Dictionary : ')
print(newDict_done)
# Out:
# Filtered Dictionary :
# [{'id': '119961', 'slug': '4', 'path': 'https://naimi.kz/specialist/119961?service=4', 'scraped': 0, 'name': 'Екатерина Дерендяева', 'age': '41 год', 'exp': 'в Naimi.kz 1 год 0 мес.', 'price': 'от 5000 тг', 'spec_lvl': '4', 'review-count': '10', 'review-positive': 'width: 90%;', 'review-neutral': 'width: 0%;', 'review-negative': 'width: 10%;', 'edu_prof': 'Нұргүл Көпжасар', 'edu_university': None, 'tel': '+77789950453'}, {'id': '278765', 'slug': '4', 'path': 'https://naimi.kz/specialist/278765?service=4', 'scraped': 0, 'name': 'Талгат Касенов', 'age': '23 года', 'exp': 'в Naimi.kz недавно', 'price': 'от тг', 'spec_lvl': '2', 'review-count': '1', 'review-positive': 'width: 100%;', 'review-neutral': 'width: 0%;', 'review-negative': 'width: 0%;', 'edu_prof': 'Техник строитель', 'edu_university': 'Колледж Инновационного Евразиского Университета, 2', 'tel': '+77768184819'}, {'id': '250134', 'slug': '4', 'path': 'https://naimi.kz/specialist/250134?service=4', 'scraped': 0, 'name': 'Гульбану Мухамедиева', 'age': '38 лет', 'exp': 'в Naimi.kz недавно', 'price': 'от 7000 тг', 'spec_lvl': '3', 'review-count': '0', 'review-positive': 'width: 0%;', 'review-neutral': 'width: 0%;', 'review-negative': 'width: 0%;', 'edu_prof': 'Нұргүл Көпжасар', 'edu_university': None, 'tel': '+77471630910'}, {'id': '187126', 'slug': '4', 'path': 'https://naimi.kz/specialist/187126?service=4', 'scraped': 0, 'name': 'Зульфия Давлетьярова', 'age': '30 лет', 'exp': 'в Naimi.kz недавно', 'price': 'от 2000 тг', 'spec_lvl': '3', 'review-count': '2', 'review-positive': 'width: 100%;', 'review-neutral': 'width: 0%;', 'review-negative': 'width: 0%;', 'edu_prof': 'Финансист', 'edu_university': 'ЗКГК, 1', 'tel': '+77774077030'}, {'id': '113762', 'slug': '4', 'path': 'https://naimi.kz/specialist/113762?service=4', 'scraped': 0, 'name': 'Шакризат Ыскакова', 'age': '29 лет', 'exp': 'в Naimi.kz 1 год 0 мес.', 'price': 'от 10000 тг', 'spec_lvl': '11', 'review-count': '95', 'review-positive': 'width: 91.5789%;', 'review-neutral': 'width: 2.10526%;', 'review-negative': 'width: 6.31579%;', 'edu_prof': 'Юрист', 'edu_university': 'М.АУЕЗОВ, 1', 'tel': '+77078584326'}, {'id': '279371', 'slug': '4', 'path': 'https://naimi.kz/specialist/279371?service=4', 'scraped': 0, 'name': 'Динара Даутахунова', 'age': '38 лет', 'exp': 'в Naimi.kz недавно', 'price': 'от тг', 'spec_lvl': '3', 'review-count': '4', 'review-positive': 'width: 100%;', 'review-neutral': 'width: 0%;', 'review-negative': 'width: 0%;', 'edu_prof': 'Разнорабочии', 'edu_university': 'Средняя шк им Абая, 1', 'tel': '+77478976267'}, {'id': '95192', 'slug': '4', 'path': 'https://naimi.kz/specialist/95192?service=4', 'scraped': 0, 'name': 'Анастасия Бондарева', 'age': '43 года', 'exp': 'в Naimi.kz 1 год 0 мес.', 'price': 'от 5000 тг', 'spec_lvl': '6', 'review-count': '25', 'review-positive': 'width: 92%;', 'review-neutral': 'width: 0%;', 'review-negative': 'width: 8%;', 'edu_prof': '', 'edu_university': 'Каз Гу, 3', 'tel': '+77075699132'}, {'id': '267322', 'slug': '4', 'path': 'https://naimi.kz/specialist/267322?service=4', 'scraped': 0, 'name': 'Анастасия Кишкина', 'age': '34 года', 'exp': 'в Naimi.kz недавно', 'price': 'от 6000 тг', 'spec_lvl': '2', 'review-count': '0', 'review-positive': 'width: 0%;', 'review-neutral': 'width: 0%;', 'review-negative': 'width: 0%;', 'edu_prof': 'Мастер маникюра и педикюра', 'edu_university': 'Курсы престиж, 1', 'tel': '+77052776567'}, {'id': '50716', 'slug': '4', 'path': 'https://naimi.kz/specialist/50716?service=4', 'scraped': 0, 'name': 'Эльмира Зурдинова', 'age': '33 года', 'exp': 'в Naimi.kz 2 года 0 мес.', 'price': 'от 6000 тг', 'spec_lvl': '8', 'review-count': '37', 'review-positive': 'width: 91.8919%;', 'review-neutral': 'width: 8.10811%;', 'review-negative': 'width: 0%;', 'edu_prof': 'Нұргүл Көпжасар', 'edu_university': None, 'tel': '+77477258347'}, {'id': '269453', 'slug': '4', 'path': 'https://naimi.kz/specialist/269453?service=4', 'scraped': 0, 'name': 'Нургул Кошанова', 'age': '23 ...

# %%
len(datas)
# Out:
# 16033

# %%
len(newDict)
# Out:
# 15844

# %%
len(newDict_done)
# Out:
# 189

# %%
q+=1

# %%
q

# %%
datas2=datas.copy()

# %%
df=pd.DataFrame(datas)

# %%
df.head(10)
# Out:
#        id slug                                          path  scraped  \
# 0  119961    4  https://naimi.kz/specialist/119961?service=4        0
# 1  278765    4  https://naimi.kz/specialist/278765?service=4        0
# 2  250134    4  https://naimi.kz/specialist/250134?service=4        0
# 3  187126    4  https://naimi.kz/specialist/187126?service=4        0
# 4  113762    4  https://naimi.kz/specialist/113762?service=4        0
# 5  279371    4  https://naimi.kz/specialist/279371?service=4        0
# 6   95192    4   https://naimi.kz/specialist/95192?service=4        0
# 7  267322    4  https://naimi.kz/specialist/267322?service=4        0
# 8   50716    4   https://naimi.kz/specialist/50716?service=4        0
# 9  269453    4  https://naimi.kz/specialist/269453?service=4        0
#
#                    name      age                       exp        price  \
# 0  Екатерина Дерендяева   41 год   в Naimi.kz 1 год 0 мес.   от 5000 тг
# 1        Талгат Касенов  23 года        в Naimi.kz недавно        от тг
# 2  Гульбану Мухамедиева   38 лет        в Naimi.kz недавно   от 7000 тг
# 3  Зульфия Давлетьярова   30 лет        в Naimi.kz недавно   от 2000 тг
# 4     Шакризат Ыскакова   29 лет   в Naimi.kz 1 год 0 мес.  от 10000 тг
# 5    Динара Даутахунова   38 лет        в Naimi.kz недавно        от тг
# 6   Анастасия Бондарева  43 года   в Naimi.kz 1 год 0 мес.   от 5000 тг
# 7     Анастасия Кишкина  34 года        в Naimi.kz недавно   от 6000 тг
# 8     Эльмира Зурдинова  33 года  в Naimi.kz 2 года 0 мес.   от 6000 тг
# 9       Нургул Кошанова  23 года        в Naimi.kz недавно  29 СЕНТЯБРЯ
#
#   spec_lvl review-count   review-positive    review-neutral   review-negative  \
# 0        4           10       width: 90%;        width: 0%;       width: 10%;
# 1        2            1      width: 100%;        width: 0%;        width: 0%;
# 2        3            0        width: 0%;        width: 0%;        width: 0%;
# 3        3            2      width: 100%;        width: 0%;        width: 0%;
# 4       11           95  width: 91.5789%;  width: 2.10526%;  width: 6.31579%;
# 5        3            4      width: 100%;        width: 0%;        width: 0%;
# 6        6           25       width: 92%;        width: 0%;        width: 8%;
# 7        2            0        width: 0%;        width: 0%;        width: 0%;
# 8        8           37  width: 91.8919%;  width: 8.10811%;        width: 0%;
# 9        2            1        width: 0%;        width: 0%;      width: 100%;
#
#                      edu_prof  \
# 0             Нұргүл Көпжасар
# 1            Техник строитель
# 2             Нұргүл Көпжасар
# 3                   Финансист
# 4                       Юрист
# 5                Разнорабочии
# 6
# 7  Мастер маникюра и педикюра
# 8             Нұргүл Көпжасар
# 9                        None
#
#                                       edu_university           tel
# 0                                               None  +77789950453
# 1  Колледж Инновационного Евразиского Университет...  +77768184819
# 2                                               None  +77471630910
# 3                                            ЗКГК, 1  +77774077030
# 4                                        М.АУЕЗОВ, 1  +77078584326
# 5                              Средняя шк им Абая, 1  +77478976267
# 6                                          Каз Гу, 3  +77075699132
# 7                                   Курсы престиж, 1  +77052776567
# 8                                               None  +77477258347
# 9                                               None  +77758302897

# %%
da

# %%
with open(r'datas2.pickle', 'wb') as output:
    pickle.dump(datas2, output)

# %%
print(browser.find_elements_by_xpath("//span[@class='flex-item fixed-size review--review-count mr-4']")

# %%
url = 'https://naimi.kz/specialist/113762?service=4#/'
req = requests.get(url)
content, browser = chrome(url)
html_r = HTML(html=content)
browser.add_cookie({"name" : "_session_public", "value" : "EMDkrM2AsLpsnFEu3L9bkz6oS7QUnbVWyXBOW1SpMpozxRwuSTZHwkIxaia0zESLkJUK6BxDmOAv3L7yycPsWi6voEhuZkW7iB7J"})
browser.find_element_by_xpath("//button[@class='btn blue mr-3 flex-item']").click()

# %%
print(browser.get_cookies())

# %%
browser.add_cookie({"name" : "_session_public", "value" : "EMDkrM2AsLpsnFEu3L9bkz6oS7QUnbVWyXBOW1SpMpozxRwuSTZHwkIxaia0zESLkJUK6BxDmOAv3L7yycPsWi6voEhuZkW7iB7J"})

# %%
content_blocks = browser.find_elements_by_class_name("specialist--profile")

# %%
element_price = browser.find_element_by_xpath("//div[@class='flex-item fixed-size right']").text

# %%
element_price

# %%
browser.find_elements_by_xpath("//span[@class='specialist--level text md']")[0].text

# %%
element_age = browser.find_elements_by_xpath("//span[@class='text md gray-75 d-ib mr-1']")[0].text

# %%
element_exp = browser.find_elements_by_xpath("//span[@class='text md gray-75 d-ib ml-1']")[0].text

# %%
element_age

# %%
element_exp

# %%
element_name

# %%
# f = open("naimi.kz_cookies.txt", "r")
# print(f.read())

# %%
element_btn = browser.find_element_by_xpath("//button[@class='btn blue width-100p ta-c mgb-2']")

# %%
element_btn.text

# %%
element_btn.click()

# %%
element_btn_tel = browser.find_element_by_xpath("//a[@class='btn blue width-100p ta-c mgb-2']").text

# %%
print(element_btn_tel)

# %%
browser.find_element_by_xpath("//div[@class='review--review-bars positive']//div[@class='review--review-bar']").get_attribute("style")

# %%
browser.find_element_by_xpath("//div[@class='review--review-bars negative']//div[@class='review--review-bar']").get_attribute("style")

# %%
browser.find_element_by_xpath("//div[@class='review--review-bars neutral']//div[@class='review--review-bar']").get_attribute("style")

# %%
browser.find_element_by_xpath("//div[@class='text md']").text

# %%
browser.find_element_by_xpath("//div[@class='text sm gray']").text
