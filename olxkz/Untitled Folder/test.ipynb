# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver import ActionChains
from bs4 import BeautifulSoup
import requests
from urllib.parse import urljoin
import pandas as pd
import time

# %%
import re
import requests
from requests_html import HTML
import pandas as pd

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver import DesiredCapabilities
from selenium.common.exceptions import TimeoutException, NoSuchElementException, TimeoutException, ElementClickInterceptedException

# %%
def chrome(url):
    # support to get response status and headers
    d = DesiredCapabilities.CHROME
    d['loggingPrefs'] = {'performance': 'ALL'}
    opt = webdriver.ChromeOptions()
#     opt.add_argument("--headless")
#     opt.add_argument("--disable-xss-auditor")
    opt.add_argument("--disable-web-security")
    opt.add_argument("--allow-running-insecure-content")
    opt.add_argument("--no-sandbox")
    opt.add_argument("--disable-setuid-sandbox")
    opt.add_argument("--disable-webgl")
#     opt.add_argument("--disable-popup-blocking")
    # prefs = {"profile.managed_default_content_settings.images": 2,
    #          'notifications': 2,
    #          }
    # opt.add_experimental_option("prefs", prefs)
    browser = webdriver.Chrome(options=opt,desired_capabilities=d)
#     browser.add_cookie({"name" : "_session_public", "value" : "EMDkrM2AsLpsnFEu3L9bkz6oS7QUnbVWyXBOW1SpMpozxRwuSTZHwkIxaia0zESLkJUK6BxDmOAv3L7yycPsWi6voEhuZkW7iB7J"})
#     browser.add_cookie({"name" : "city", "value" : "{%22id%22:1%2C%22name%22:%22%D0%90%D0%BB%D0%BC%D0%B0%D1%82%D1%8B%22%2C%22slug%22:%22almaty%22%2C%22is_disabled%22:false%2C%22deposit_rate%22:1%2C%22label%22:%22empty%22%2C%22country_id%22:1%2C%22latitude%22:43.221313%2C%22longitude%22:76.955436}"})
    browser.implicitly_wait(10)
    browser.set_page_load_timeout(20)
    browser.get(url)
    return browser.page_source, browser

# %%
# /en/fabric/7137786-genevieve-floral-by-crystal_walen
def extract_id_slug(url_path):
    regex = r"^[^\s]+/(?P<id>\d+)./?service=(?P<service>\d+)"
    group = re.match(regex, url_path)
    if not group:
        return None, None
    return group['id'], group['service']

# %%
category=[]
list_cat_hrefs=[]
url = 'https://naimi.kz/#/'
req = requests.get(url)
content, browser = chrome(url)
browser.find_element_by_xpath("//button[@class='btn blue mr-3 flex-item']").click()

# %%
elements=browser.find_elements_by_class_name("category")
for i in elements:
    elements = i.find_elements_by_tag_name("a")
    for el in elements:
        category.append(el)
        list_cat_hrefs.append(el.get_attribute("href"))

# %%
list_cat_hrefs

# %%
list_sub_cat_hrefs=[]
for l in list_cat_hrefs:
    req = requests.get(l)
    content, browser = chrome(l)
    cats=browser.find_elements_by_xpath("//a[@class='categories--service blue outline pt-1 pb-1 pl-2 pr-2']")
    for i in cats:
        print(i.get_attribute("href"))
        list_sub_cat_hrefs.append(i.get_attribute("href"))

# %%
len(list_sub_cat_hrefs)

# %%
datas = []
for cat in list_sub_cat_hrefs:
    i=1
    result = None
    text_found=r'Рекомендованные специалисты'
    while text_found is not None:
        try:
            url = '{}?page={}#/'.format(cat,i)
            req = requests.get(url)
            content, browser = chrome(url)
            html_r = HTML(html=content)
            text_found = re.search(r'Рекомендованные специалисты', content)
            if text_found is None:
                break
            list_of_hrefs=[]
            a_elements = []
            content_blocks = browser.find_elements_by_class_name("service-specialists")
            for block in content_blocks:
                elements = block.find_elements_by_tag_name("a")
                for el in elements:
                    a_elements.append(el)
                    list_of_hrefs.append(el.get_attribute("href"))
                    fabric_links = [x for x in list(list_of_hrefs) if x.startswith("https://naimi.kz/specialist/")]
            for path in fabric_links:
                id_, slug_ = extract_id_slug(path)
                print(id_, slug_)
                data = {
                    "id": id_,
                    "slug": slug_,
                    "path": path,
                    "scraped": 0 # True / False -> 1 / 0 
                }
                datas.append(data)
            print('page {}'.format(i))   
            i+=1    
        except:
            break

# %%
datas

# %%
datas1=datas.copy()

# %%
# !pipenv install pickle

# %%
print(datas1)
# Out:
# [{'id': '119961', 'slug': '4', 'path': 'https://naimi.kz/specialist/119961?service=4', 'scraped': 0}, {'id': '278765', 'slug': '4', 'path': 'https://naimi.kz/specialist/278765?service=4', 'scraped': 0}, {'id': '250134', 'slug': '4', 'path': 'https://naimi.kz/specialist/250134?service=4', 'scraped': 0}, {'id': '187126', 'slug': '4', 'path': 'https://naimi.kz/specialist/187126?service=4', 'scraped': 0}, {'id': '113762', 'slug': '4', 'path': 'https://naimi.kz/specialist/113762?service=4', 'scraped': 0}, {'id': '279371', 'slug': '4', 'path': 'https://naimi.kz/specialist/279371?service=4', 'scraped': 0}, {'id': '95192', 'slug': '4', 'path': 'https://naimi.kz/specialist/95192?service=4', 'scraped': 0}, {'id': '267322', 'slug': '4', 'path': 'https://naimi.kz/specialist/267322?service=4', 'scraped': 0}, {'id': '50716', 'slug': '4', 'path': 'https://naimi.kz/specialist/50716?service=4', 'scraped': 0}, {'id': '269453', 'slug': '4', 'path': 'https://naimi.kz/specialist/269453?service=4', 'scraped': 0}, {'id': '261199', 'slug': '4', 'path': 'https://naimi.kz/specialist/261199?service=4', 'scraped': 0}, {'id': '194264', 'slug': '4', 'path': 'https://naimi.kz/specialist/194264?service=4', 'scraped': 0}, {'id': '202424', 'slug': '4', 'path': 'https://naimi.kz/specialist/202424?service=4', 'scraped': 0}, {'id': '282664', 'slug': '4', 'path': 'https://naimi.kz/specialist/282664?service=4', 'scraped': 0}, {'id': '13737', 'slug': '4', 'path': 'https://naimi.kz/specialist/13737?service=4', 'scraped': 0}, {'id': '229599', 'slug': '4', 'path': 'https://naimi.kz/specialist/229599?service=4', 'scraped': 0}, {'id': '283821', 'slug': '4', 'path': 'https://naimi.kz/specialist/283821?service=4', 'scraped': 0}, {'id': '251496', 'slug': '4', 'path': 'https://naimi.kz/specialist/251496?service=4', 'scraped': 0}, {'id': '251063', 'slug': '4', 'path': 'https://naimi.kz/specialist/251063?service=4', 'scraped': 0}, {'id': '254912', 'slug': '4', 'path': 'https://naimi.kz/specialist/254912?service=4', 'scraped': 0}, {'id': '245275', 'slug': '4', 'path': 'https://naimi.kz/specialist/245275?service=4', 'scraped': 0}, {'id': '107843', 'slug': '4', 'path': 'https://naimi.kz/specialist/107843?service=4', 'scraped': 0}, {'id': '105445', 'slug': '4', 'path': 'https://naimi.kz/specialist/105445?service=4', 'scraped': 0}, {'id': '112806', 'slug': '4', 'path': 'https://naimi.kz/specialist/112806?service=4', 'scraped': 0}, {'id': '63390', 'slug': '4', 'path': 'https://naimi.kz/specialist/63390?service=4', 'scraped': 0}, {'id': '133015', 'slug': '4', 'path': 'https://naimi.kz/specialist/133015?service=4', 'scraped': 0}, {'id': '212518', 'slug': '4', 'path': 'https://naimi.kz/specialist/212518?service=4', 'scraped': 0}, {'id': '30002', 'slug': '4', 'path': 'https://naimi.kz/specialist/30002?service=4', 'scraped': 0}, {'id': '13569', 'slug': '4', 'path': 'https://naimi.kz/specialist/13569?service=4', 'scraped': 0}, {'id': '119750', 'slug': '4', 'path': 'https://naimi.kz/specialist/119750?service=4', 'scraped': 0}, {'id': '80429', 'slug': '4', 'path': 'https://naimi.kz/specialist/80429?service=4', 'scraped': 0}, {'id': '282930', 'slug': '4', 'path': 'https://naimi.kz/specialist/282930?service=4', 'scraped': 0}, {'id': '83536', 'slug': '4', 'path': 'https://naimi.kz/specialist/83536?service=4', 'scraped': 0}, {'id': '125990', 'slug': '4', 'path': 'https://naimi.kz/specialist/125990?service=4', 'scraped': 0}, {'id': '128773', 'slug': '4', 'path': 'https://naimi.kz/specialist/128773?service=4', 'scraped': 0}, {'id': '217765', 'slug': '4', 'path': 'https://naimi.kz/specialist/217765?service=4', 'scraped': 0}, {'id': '40631', 'slug': '4', 'path': 'https://naimi.kz/specialist/40631?service=4', 'scraped': 0}, {'id': '205352', 'slug': '4', 'path': 'https://naimi.kz/specialist/205352?service=4', 'scraped': 0}, {'id': '282851', 'slug': '4', 'path': 'https://naimi.kz/specialist/282851?service=4', 'scraped': 0}, {'id': '284220', 'slug': '4', 'path': 'https://naimi.kz/specialist/284220?serv ...

# %%
import pickle

# %%
with open(r'datas1.pickle', 'wb') as output:
    pickle.dump(datas, output)

# %%
with open(r'datas.pickle', 'rb') as data:
     datas = pickle.load(data)

# %%
len(datas[:8000])

# %%
len(datas[4000:8000])

# %%
start = time.time()
i=1
for p in datas[:1000]:
    try:
        if i%20!=0:
            print(p.get('path'))
            url = p.get('path')
            req = requests.get(url)
            content, browser = chrome(url)
            html_r = HTML(html=content)
            browser.add_cookie({"name" : "_session_public", "value" : "Of5freEuTmKgcl9VrrY4TOpUe885f92sollNnHmLVH4H3DN1CN79leQv2HFTqpcMKj0K547SPIIc9jtDRtS4r12I7PxXvdK8VKko"})
            try:
                browser.find_element_by_xpath("//button[@class='btn blue mr-3 flex-item']").click()
            except NoSuchElementException:
                pass
            except ElementClickInterceptedException:
                pass
            try:
                p["name"] = element_name = browser.find_element_by_xpath("//div[@class='mb-half text lg verified']").text
            except NoSuchElementException:
                p["name"]=None
                pass
            try:
                p["age"] = browser.find_elements_by_xpath("//span[@class='text md gray-75 d-ib mr-1']")[0].text
            except NoSuchElementException:
                p["age"]=None
                pass
            try:
                p["exp"] = browser.find_elements_by_xpath("//span[@class='text md gray-75 d-ib ml-1']")[0].text
            except NoSuchElementException:
                p["exp"]=None
                pass
            try:
                p['price']= browser.find_element_by_xpath("//div[@class='flex-item fixed-size right']").text
            except NoSuchElementException:
                p['price']=None
                pass
            try:
                p['spec_lvl']=browser.find_elements_by_xpath("//span[@class='specialist--level text md']")[0].text
            except NoSuchElementException:
                p['spec_lvl']=None
                pass
            try:
                p['review-count']=browser.find_elements_by_xpath("//div[@class='flex-item fixed-size review--review-count mr-4']")[0].text
            except NoSuchElementException:
                p['review-count']=None
                pass
            try:
                p['review-positive']=browser.find_element_by_xpath("//div[@class='review--review-bars positive']//div[@class='review--review-bar']").get_attribute("style")
            except NoSuchElementException:
                p['review-positive']=None
                pass
            try:
                p['review-neutral']=browser.find_element_by_xpath("//div[@class='review--review-bars neutral']//div[@class='review--review-bar']").get_attribute("style")
            except NoSuchElementException:
                p['review-neutral']=None
                pass
            try:
                p['review-negative']=browser.find_element_by_xpath("//div[@class='review--review-bars negative']//div[@class='review--review-bar']").get_attribute("style")
            except NoSuchElementException:
                p['review-negative']=None
                pass
            try:
                p['edu_prof']=browser.find_element_by_xpath("//div[@class='text md']").text
            except NoSuchElementException:
                p['edu_prof']=None
                pass
            try:
                p['edu_university']=browser.find_element_by_xpath("//div[@class='text sm gray']").text
            except NoSuchElementException:
                p['edu_university']=None
                pass
            try:
                browser.find_element_by_xpath("//button[@class='btn blue width-100p ta-c mgb-2']").click()
                print("clicked")
                p["tel"] = browser.find_element_by_xpath("//a[@class='btn blue width-100p ta-c mgb-2']").text
                print("tel saved")
            except NoSuchElementException:
                time.sleep(5*60)
                browser.find_element_by_xpath("//button[@class='btn blue width-100p ta-c mgb-2']").click()
                p["tel"] = browser.find_element_by_xpath("//a[@class='btn blue width-100p ta-c mgb-2']").text
                pass
            except ElementClickInterceptedException:
                time.sleep(5*60)
                browser.find_element_by_xpath("//button[@class='btn blue width-100p ta-c mgb-2']").click()
                p["tel"] = browser.find_element_by_xpath("//a[@class='btn blue width-100p ta-c mgb-2']").text
                pass
            except TimeoutException:
                time.sleep(5*60)
                browser.find_element_by_xpath("//button[@class='btn blue width-100p ta-c mgb-2']").click()
                p["tel"] = browser.find_element_by_xpath("//a[@class='btn blue width-100p ta-c mgb-2']").text
                pass

        else:
            time.sleep(5*60)
    except NoSuchElementException:
        pass
    except TimeoutException:
        pass

end = time.time() - start

print(end)
# Out:
# https://naimi.kz/specialist/119961?service=4
# clicked
# https://naimi.kz/specialist/278765?service=4
# clicked
# https://naimi.kz/specialist/250134?service=4
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# <ipython-input-23-5777a3c19c9e> in <module>
#      73             try:
# ---> 74                 browser.find_element_by_xpath("//button[@class='btn blue width-100p ta-c mgb-2']").click()
#      75                 print("clicked")
#
# ~/opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webelement.py in click(self)
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#
# ~/opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#
# ~/opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# ElementClickInterceptedException: Message: element click intercepted: Element <button class="btn blue width-100p ta-c mgb-2">...</button> is not clickable at point (862, 162). Other element would receive the click: <a data-v-3cb74fcc="" href="#" class="flex v-centered pdx-3 pdy-1">...</a>
#   (Session info: chrome=86.0.4240.193)
#
#
# During handling of the above exception, another exception occurred:
#
# ElementClickInterceptedException          Traceback (most recent call last)
# <ipython-input-23-5777a3c19c9e> in <module>
#      83             except ElementClickInterceptedException:
#      84                 time.sleep(5*60)
# ---> 85                 browser.find_element_by_xpath("//button[@class='btn blue width-100p ta-c mgb-2']").click()
#      86                 p["tel"] = browser.find_element_by_xpath("//a[@class='btn blue width-100p ta-c mgb-2']").text
#      87                 pass
#
# ~/opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# ElementClickInterceptedException: Message: element click intercepted: Element <button class="btn blue width-100p ta-c mgb-2">...</button> is not clickable at point (862, 162). Other element would receive the click: <a data-v-3cb74fcc="" href="#" class="flex v-centered pdx-3 pdy-1">...</a>
#   (Session info: chrome=86.0.4240.193)

# %%
datas1[4000:4001]
# Out:
# [{'id': '274895',
#   'slug': '15',
#   'path': 'https://naimi.kz/specialist/274895?service=15',
#   'scraped': 0,
#   'name': 'Мирзаахмет Айдаркулов',
#   'age': '43 года',
#   'exp': 'в Naimi.kz недавно',
#   'price': '15 ОКТЯБРЯ',
#   'spec_lvl': '2',
#   'review-count': '1',
#   'review-positive': 'width: 0%;',
#   'review-neutral': 'width: 100%;',
#   'review-negative': 'width: 0%;',
#   'edu_prof': None,
#   'edu_university': None,
#   'tel': '+77079377095'}]

# %%
print(datas1)
# Out:
# [{'id': '119961', 'slug': '4', 'path': 'https://naimi.kz/specialist/119961?service=4', 'scraped': 0}, {'id': '278765', 'slug': '4', 'path': 'https://naimi.kz/specialist/278765?service=4', 'scraped': 0}, {'id': '250134', 'slug': '4', 'path': 'https://naimi.kz/specialist/250134?service=4', 'scraped': 0}, {'id': '187126', 'slug': '4', 'path': 'https://naimi.kz/specialist/187126?service=4', 'scraped': 0}, {'id': '113762', 'slug': '4', 'path': 'https://naimi.kz/specialist/113762?service=4', 'scraped': 0}, {'id': '279371', 'slug': '4', 'path': 'https://naimi.kz/specialist/279371?service=4', 'scraped': 0}, {'id': '95192', 'slug': '4', 'path': 'https://naimi.kz/specialist/95192?service=4', 'scraped': 0}, {'id': '267322', 'slug': '4', 'path': 'https://naimi.kz/specialist/267322?service=4', 'scraped': 0}, {'id': '50716', 'slug': '4', 'path': 'https://naimi.kz/specialist/50716?service=4', 'scraped': 0}, {'id': '269453', 'slug': '4', 'path': 'https://naimi.kz/specialist/269453?service=4', 'scraped': 0}, {'id': '261199', 'slug': '4', 'path': 'https://naimi.kz/specialist/261199?service=4', 'scraped': 0}, {'id': '194264', 'slug': '4', 'path': 'https://naimi.kz/specialist/194264?service=4', 'scraped': 0}, {'id': '202424', 'slug': '4', 'path': 'https://naimi.kz/specialist/202424?service=4', 'scraped': 0}, {'id': '282664', 'slug': '4', 'path': 'https://naimi.kz/specialist/282664?service=4', 'scraped': 0}, {'id': '13737', 'slug': '4', 'path': 'https://naimi.kz/specialist/13737?service=4', 'scraped': 0}, {'id': '229599', 'slug': '4', 'path': 'https://naimi.kz/specialist/229599?service=4', 'scraped': 0}, {'id': '283821', 'slug': '4', 'path': 'https://naimi.kz/specialist/283821?service=4', 'scraped': 0}, {'id': '251496', 'slug': '4', 'path': 'https://naimi.kz/specialist/251496?service=4', 'scraped': 0}, {'id': '251063', 'slug': '4', 'path': 'https://naimi.kz/specialist/251063?service=4', 'scraped': 0}, {'id': '254912', 'slug': '4', 'path': 'https://naimi.kz/specialist/254912?service=4', 'scraped': 0}, {'id': '245275', 'slug': '4', 'path': 'https://naimi.kz/specialist/245275?service=4', 'scraped': 0}, {'id': '107843', 'slug': '4', 'path': 'https://naimi.kz/specialist/107843?service=4', 'scraped': 0}, {'id': '105445', 'slug': '4', 'path': 'https://naimi.kz/specialist/105445?service=4', 'scraped': 0}, {'id': '112806', 'slug': '4', 'path': 'https://naimi.kz/specialist/112806?service=4', 'scraped': 0}, {'id': '63390', 'slug': '4', 'path': 'https://naimi.kz/specialist/63390?service=4', 'scraped': 0}, {'id': '133015', 'slug': '4', 'path': 'https://naimi.kz/specialist/133015?service=4', 'scraped': 0}, {'id': '212518', 'slug': '4', 'path': 'https://naimi.kz/specialist/212518?service=4', 'scraped': 0}, {'id': '30002', 'slug': '4', 'path': 'https://naimi.kz/specialist/30002?service=4', 'scraped': 0}, {'id': '13569', 'slug': '4', 'path': 'https://naimi.kz/specialist/13569?service=4', 'scraped': 0}, {'id': '119750', 'slug': '4', 'path': 'https://naimi.kz/specialist/119750?service=4', 'scraped': 0}, {'id': '80429', 'slug': '4', 'path': 'https://naimi.kz/specialist/80429?service=4', 'scraped': 0}, {'id': '282930', 'slug': '4', 'path': 'https://naimi.kz/specialist/282930?service=4', 'scraped': 0}, {'id': '83536', 'slug': '4', 'path': 'https://naimi.kz/specialist/83536?service=4', 'scraped': 0}, {'id': '125990', 'slug': '4', 'path': 'https://naimi.kz/specialist/125990?service=4', 'scraped': 0}, {'id': '128773', 'slug': '4', 'path': 'https://naimi.kz/specialist/128773?service=4', 'scraped': 0}, {'id': '217765', 'slug': '4', 'path': 'https://naimi.kz/specialist/217765?service=4', 'scraped': 0}, {'id': '40631', 'slug': '4', 'path': 'https://naimi.kz/specialist/40631?service=4', 'scraped': 0}, {'id': '205352', 'slug': '4', 'path': 'https://naimi.kz/specialist/205352?service=4', 'scraped': 0}, {'id': '282851', 'slug': '4', 'path': 'https://naimi.kz/specialist/282851?service=4', 'scraped': 0}, {'id': '284220', 'slug': '4', 'path': 'https://naimi.kz/specialist/284220?serv ...

# %%
print(browser.find_elements_by_xpath("//span[@class='flex-item fixed-size review--review-count mr-4']")

# %%
url = 'https://naimi.kz/specialist/113762?service=4#/'
req = requests.get(url)
content, browser = chrome(url)
html_r = HTML(html=content)
browser.add_cookie({"name" : "_session_public", "value" : "EMDkrM2AsLpsnFEu3L9bkz6oS7QUnbVWyXBOW1SpMpozxRwuSTZHwkIxaia0zESLkJUK6BxDmOAv3L7yycPsWi6voEhuZkW7iB7J"})
browser.find_element_by_xpath("//button[@class='btn blue mr-3 flex-item']").click()

# %%
print(browser.get_cookies())

# %%
browser.add_cookie({"name" : "_session_public", "value" : "EMDkrM2AsLpsnFEu3L9bkz6oS7QUnbVWyXBOW1SpMpozxRwuSTZHwkIxaia0zESLkJUK6BxDmOAv3L7yycPsWi6voEhuZkW7iB7J"})

# %%
content_blocks = browser.find_elements_by_class_name("specialist--profile")

# %%
element_price = browser.find_element_by_xpath("//div[@class='flex-item fixed-size right']").text

# %%
element_price

# %%
browser.find_elements_by_xpath("//span[@class='specialist--level text md']")[0].text

# %%
element_age = browser.find_elements_by_xpath("//span[@class='text md gray-75 d-ib mr-1']")[0].text

# %%
element_exp = browser.find_elements_by_xpath("//span[@class='text md gray-75 d-ib ml-1']")[0].text

# %%
element_age

# %%
element_exp

# %%
element_name

# %%
# f = open("naimi.kz_cookies.txt", "r")
# print(f.read())

# %%
element_btn = browser.find_element_by_xpath("//button[@class='btn blue width-100p ta-c mgb-2']")

# %%
element_btn.text

# %%
element_btn.click()

# %%
element_btn_tel = browser.find_element_by_xpath("//a[@class='btn blue width-100p ta-c mgb-2']").text

# %%
print(element_btn_tel)

# %%
browser.find_element_by_xpath("//div[@class='review--review-bars positive']//div[@class='review--review-bar']").get_attribute("style")

# %%
browser.find_element_by_xpath("//div[@class='review--review-bars negative']//div[@class='review--review-bar']").get_attribute("style")

# %%
browser.find_element_by_xpath("//div[@class='review--review-bars neutral']//div[@class='review--review-bar']").get_attribute("style")

# %%
browser.find_element_by_xpath("//div[@class='text md']").text

# %%
browser.find_element_by_xpath("//div[@class='text sm gray']").text
